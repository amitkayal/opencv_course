# %% [markdown]
# # <font style="color:blue">Project 1 - Part 2: Train an Image Classifier from Scratch</font>
# As discussed in the previous notebook, the steps for training Neural Networks are:
#
# - Step 1 - Understand your problem
# - Step 2A - Get the data
# - Step 2B - Explore & Understand your data
# - Step 2C - Create a sample data from the dataset
# - Step 3 - Data Preparation
# - Step 4 - Train a simple model on sample data and check the pipeline before proceeding to train the full network
# - Step 5 - Train on Full Data
# - Step 6 - Improve your model
#
# You have already gone through Steps 1 through 4 in the previous notebook and you can use them in this notebook as well.
#
# In this notebook You will implement Steps 5 & 6 completely from scratch. You should design a model which achieves 85% validation accuracy on the given dataset.
#
# There are **70 points** for this notebook. <font style="color:red">The sections which carry marks are written in Red for easy reference.</font>

# %% [markdown]
# Since you have received Microsoft Azure Credits, you can use the GPUs for training the network (We will provide instructions on how to set it up in case you are not able to figure it out yourself). After you have completed the assignment, upload and submit it on the portal so that we can check and provide feedback.

# %% [markdown]
# <font style="color:red">You will use the full data to train the network. You need to achieve 85% accuracy for validation data to successfully complete this assignment.</font>
#
# <font style="color:red">As mentioned earlier, you should build your own model and not use any pre-trained models/weights.</font>
#
# After you have completed the assignment, <font style="color:red">upload and submit the notebook and the models folder on the portal</font> so that we can check and provide feedback.

# %% [markdown]
# # <font style="color:blue">Step 1: Understand your problem </font>
# Already covered in previous notebook.

# %% [markdown]
# # <font style="color:blue">Step 2: Get the data </font>
# Already covered in previous notebook.

# %%
# !wget "https://www.dropbox.com/sh/n5nya3g3airlub6/AACi7vaUjdTA0t2j_iKWgp4Ra?dl=1" -O data.zip

# %% [markdown]
# ### <font style="color:green">Extract the data</font>

# %%
# !unzip -q data.zip

# %% [markdown]
# # <font style="color:blue">Step 3. Data Preparation</font>
# Already covered in previous notebook.

# %% [markdown]
# ## <font style="color:blue">3.1. Import Libraries </font>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
import os
import time

from typing import Iterable
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torchvision import datasets, transforms

from torch.optim import lr_scheduler

# %% [markdown]
# ### <font style="color:green">3.2.1. Compulsary preprocessing transforms</font>

# %%
def image_preprocess_transforms():
    
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor()
        ])
    
    return preprocess

# %% [markdown]
# ### <font style="color:green">3.2.2. Common Image Transforms</font>

# %%
def image_common_transforms(mean=(0.4611, 0.4359, 0.3905), std=(0.2193, 0.2150, 0.2109)):
    preprocess = image_preprocess_transforms()
    
    common_transforms = transforms.Compose([
        preprocess,
        transforms.Normalize(mean, std)
    ])
    
    return common_transforms

# %% [markdown]
# ### <font style="color:green">3.2.3. Mean and STD</font>

# %%
def get_mean_std(data_root, num_workers=4):
    
    transform = image_preprocess_transforms()
    
    loader = data_loader(data_root, transform)

    mean = 0.
    std = 0.
    
    for images, _ in loader:
        batch_samples = images.size(0) # batch size (the last batch can have smaller size!)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)

    mean /= len(loader.dataset)
    std /= len(loader.dataset)
    
    print('mean: {}, std: {}'.format(mean, std))
    
    return mean, std

# %% [markdown]
# ## <font style="color:blue">3.3. Data Loaders </font>

# %% [markdown]
# ### <font style="color:green">3.3.1. Data Loader for Full Data</font>
# Data loader for generating batches of data to be used by the training routine

# %%
def data_loader(data_root, transform, batch_size=16, shuffle=False, num_workers=2):
    dataset = datasets.ImageFolder(root=data_root, transform=transform)
    
    loader = torch.utils.data.DataLoader(dataset, 
                                         batch_size=batch_size,
                                         num_workers=num_workers,
                                         shuffle=shuffle)
    
    return loader

# %% [markdown]
# ## <font style="color:green">3.4. Prepare Data</font>
# The main function which uses all the above functions to generate the train and test dataloaders.

# %%
def get_data(batch_size, data_root, num_workers=4, data_augmentation=False):
#     YOUR CODE HERE
    train_data_path = os.path.join(data_root, 'training')
       
    mean, std = get_mean_std(data_root=train_data_path, num_workers=num_workers)
    
    common_transforms = image_common_transforms(mean, std)
        
    test_transforms = common_transforms
    
    # if data_augmentation is true 
    # data augmentation implementation
    if data_augmentation:    
        train_transforms = transforms.Compose([
            transforms.RandomRotation(30),
            transforms.Resize(256),
            transforms.RandomResizedCrop(224),                                    
            transforms.RandomHorizontalFlip(p = 0.5),
            transforms.RandomVerticalFlip(p = 0.5),
            transforms.ColorJitter(
                brightness = 0.4,
                contrast = 0.4,
                saturation = 0.4,
            ),            
            transforms.ToTensor(),
            transforms.Normalize(mean, std),
            transforms.RandomErasing()
        ])        
    # else do common transforms
    else:
        train_transforms = common_transforms
        
        
    # train dataloader
    
    train_loader = data_loader(train_data_path, 
                               train_transforms, 
                               batch_size=batch_size, 
                               shuffle=True, 
                               num_workers=num_workers)
    
    # test dataloader
    
    test_data_path = os.path.join(data_root, 'validation')
    
    test_loader = data_loader(test_data_path, 
                              test_transforms, 
                              batch_size=batch_size, 
                              shuffle=False, 
                              num_workers=num_workers)
    
    return train_loader, test_loader

# %% [markdown]
# # <font style="color:blue">Step 4: Train your Model</font>
# It is time to create the training pipeline and train your model on the full data.

# %% [markdown]
# ## <font style="color:red">4.1. Configurations [20 Points]</font>
# You need to make changes to the configurations. To achieve good results the parameters given in these configurations needs to be changed. You get 10 points for making the right choices.

# %% [markdown]
# ### <font style="color:green">4.1.1. System Configuration</font>
# **DO NOT CHANGE** the seed from 21. We will not be able to grade your project if that happens.

# %%
@dataclass
class SystemConfiguration:
    '''
    Describes the common system setting needed for reproducible training
    '''
    seed: int = 21  # seed number to set the state of all random number generators
    cudnn_benchmark_enabled: bool = True  # enable CuDNN benchmark for the sake of performance
    cudnn_deterministic: bool = True  # make cudnn deterministic (reproducible training)

# %% [markdown]
# ### <font style="color:green">4.1.2. Training Configuration</font>

# %%
@dataclass
class TrainingConfiguration:
    '''
    Describes configuration of the training process
    '''
    batch_size: int = 32 
    epochs_count: int = 400  
    init_learning_rate: float = 0.001  # initial learning rate for lr scheduler
    log_interval: int = 5  
    test_interval: int = 1  
    data_root: str = "./cat-dog-panda" 
    num_workers: int = 2  
    device: str = 'cuda'

# %% [markdown]
# ### <font style="color:green">4.1.3. System Setup</font>

# %%
def setup_system(system_config: SystemConfiguration) -> None:
    torch.manual_seed(system_config.seed)
    if torch.cuda.is_available():
        torch.backends.cudnn_benchmark_enabled = system_config.cudnn_benchmark_enabled
        torch.backends.cudnn.deterministic = system_config.cudnn_deterministic

# %% [markdown]
# ## <font style="color:blue">4.2. Training Function</font>
# We are already familiar with the training function. You won't need to make any changes to this.

# %%
def train(
    train_config: TrainingConfiguration, model: nn.Module, optimizer: torch.optim.Optimizer,
    train_loader: torch.utils.data.DataLoader, epoch_idx: int
) -> None:
    
    # change model in training mood
    model.train()
    
    # to get batch loss
    batch_loss = np.array([])
    
    # to get batch accuracy
    batch_acc = np.array([])
        
    for batch_idx, (data, target) in enumerate(train_loader):
        
        # clone target
        indx_target = target.clone()
        # send data to device (its is medatory if GPU has to be used)
        data = data.to(train_config.device)
        # send target to device
        target = target.to(train_config.device)

        # reset parameters gradient to zero
        optimizer.zero_grad()
        
        # forward pass to the model
        output = model(data)
        
        # cross entropy loss
        loss = F.cross_entropy(output, target)
        
        # find gradients w.r.t training parameters
        loss.backward()
        # Update parameters using gardients
        optimizer.step()
        
        batch_loss = np.append(batch_loss, [loss.item()])
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
            
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1]  
                        
        # correct prediction
        correct = pred.cpu().eq(indx_target).sum()
            
        # accuracy
        acc = float(correct) / float(len(data))
        
        batch_acc = np.append(batch_acc, [acc])
            
    epoch_loss = batch_loss.mean()
    epoch_acc = batch_acc.mean()
    print('Epoch: {} \nTrain Loss: {:.6f} Acc: {:.4f}'.format(epoch_idx, epoch_loss, epoch_acc))
    return epoch_loss, epoch_acc

# %% [markdown]
# ## <font style="color:blue">4.3. Validation Function</font>

# %%
def validate(
    train_config: TrainingConfiguration,
    model: nn.Module,
    test_loader: torch.utils.data.DataLoader,
) -> float:
    # 
    model.eval()
    test_loss = 0
    count_corect_predictions = 0
    for data, target in test_loader:
        indx_target = target.clone()
        data = data.to(train_config.device)
        
        target = target.to(train_config.device)
        
        output = model(data)
        # add loss for each mini batch
        test_loss += F.cross_entropy(output, target).item()
        
        # Score to probability using softmax
        prob = F.softmax(output, dim=1)
        
        # get the index of the max probability
        pred = prob.data.max(dim=1)[1] 
        
        # add correct prediction count
        count_corect_predictions += pred.cpu().eq(indx_target).sum()

    # average over number of mini-batches
    test_loss = test_loss / len(test_loader)  
    
    # average over number of dataset
    accuracy = 100. * count_corect_predictions / len(test_loader.dataset)
    
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, count_corect_predictions, len(test_loader.dataset), accuracy
        )
    )
    
    return test_loss, accuracy/100.0

# %% [markdown]
# ## <font style="color:blue">4.4. Save the Model</font>

# %%
def save_model(model, device, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    

    if not os.path.exists(model_dir):
        os.makedirs(model_dir)

    model_path = os.path.join(model_dir, model_file_name)

    # make sure you transfer the model to cpu.
    if device == 'cuda':
        model.to('cpu')

    # save the state_dict
    torch.save(model.state_dict(), model_path)
    
    if device == 'cuda':
        model.to('cuda')
    
    return

# %% [markdown]
# ## <font style="color:blue">4.5. Load the Model</font>

# %%
def load_model(model, model_dir='models', model_file_name='cat_dog_panda_classifier.pt'):
    model_path = os.path.join(model_dir, model_file_name)

    # loading the model and getting model parameters by using load_state_dict
    model.load_state_dict(torch.load(model_path))
    
    return model

# %% [markdown]
# ## <font style="color:blue">4.6. Main Function for Training</font>
#
# One thing to note here is that before calling the train function, we are calculating the validation loss and we know that it should be close to `log(num_classes)` and the accuracy should be close to `1/num_classes`.

# %%
def main(model, optimizer, scheduler=None, system_configuration=SystemConfiguration(), 
         training_configuration=TrainingConfiguration(), data_augmentation=True):
    
    # system configuration
    setup_system(system_configuration)

    # batch size
    batch_size_to_set = training_configuration.batch_size
    # num_workers
    num_workers_to_set = training_configuration.num_workers
    # epochs
    epoch_num_to_set = training_configuration.epochs_count

    # if GPU is available use training config, 
    # else lowers batch_size, num_workers and epochs count
    if torch.cuda.is_available():
        device = "cuda"
    else:
        device = "cpu"
        batch_size_to_set = 16
        num_workers_to_set = 4

    # data loader
    train_loader, test_loader = get_data(
        batch_size=batch_size_to_set,
        data_root=training_configuration.data_root,
        num_workers=num_workers_to_set,
        data_augmentation=data_augmentation
    )
    
    # Update training configuration
    training_configuration = TrainingConfiguration(
        device=device,
        batch_size=batch_size_to_set,
        num_workers=num_workers_to_set
    )
        
    # send model to device (GPU/CPU)
    model.to(training_configuration.device)

    best_loss = torch.tensor(np.inf)
    
    # epoch train/test loss
    epoch_train_loss = np.array([])
    epoch_test_loss = np.array([])
    
    # epch train/test accuracy
    epoch_train_acc = np.array([])
    epoch_test_acc = np.array([])
    
    # trainig time measurement
    t_begin = time.time()
    for epoch in range(training_configuration.epochs_count):
        
#         Calculate Initial Test Loss
        init_val_loss, init_val_accuracy = validate(training_configuration, model, test_loader)
        print("Initial Test Loss : {:.6f}, \nInitial Test Accuracy : {:.3f}%\n".format(init_val_loss, init_val_accuracy*100))
        
        # Train
        train_loss, train_acc = train(training_configuration, model, optimizer, train_loader, epoch)
        
        epoch_train_loss = np.append(epoch_train_loss, [train_loss])
        
        epoch_train_acc = np.append(epoch_train_acc, [train_acc])

        elapsed_time = time.time() - t_begin
        speed_epoch = elapsed_time / (epoch + 1)
        speed_batch = speed_epoch / len(train_loader)
        eta = speed_epoch * training_configuration.epochs_count - elapsed_time
        
        print(
            "Elapsed {:.2f}s, {:.2f} s/epoch, {:.2f} s/batch, ets {:.2f}s".format(
                elapsed_time, speed_epoch, speed_batch, eta
            )
        )

        # Validate
        if epoch % training_configuration.test_interval == 0:
            current_loss, current_accuracy = validate(training_configuration, model, test_loader)
            
            epoch_test_loss = np.append(epoch_test_loss, [current_loss])
        
            epoch_test_acc = np.append(epoch_test_acc, [current_accuracy])
            
            if current_loss < best_loss:
                best_loss = current_loss
                print('Model Improved. Saving the Model...\n')
                save_model(model, device=training_configuration.device)
        
                
    print("Total time: {:.2f}, Best Loss: {:.3f}".format(time.time() - t_begin, best_loss))
    
    return model, epoch_train_loss, epoch_train_acc, epoch_test_loss, epoch_test_acc

# %% [markdown]
# ## <font style="color:blue">4.7. Plot Loss and Accuracy</font>

# %%
def plot_loss_accuracy(train_loss, val_loss, train_acc, val_acc, colors, 
                       loss_legend_loc='upper center', acc_legend_loc='upper left', 
                       fig_size=(20, 10), sub_plot1=(1, 2, 1), sub_plot2=(1, 2, 2)):
    
    plt.rcParams["figure.figsize"] = fig_size
    fig = plt.figure()
    
    plt.subplot(sub_plot1[0], sub_plot1[1], sub_plot1[2])
    
    for i in range(len(train_loss)):
        x_train = range(len(train_loss[i]))
        x_val = range(len(val_loss[i]))
        
        min_train_loss = train_loss[i].min()
        
        min_val_loss = val_loss[i].min()
        
        plt.plot(x_train, train_loss[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN LOSS ({0:.4})".format(min_train_loss))
        plt.plot(x_val, val_loss[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID LOSS ({0:.4})".format(min_val_loss))
        
    plt.xlabel('epoch no.')
    plt.ylabel('loss')
    plt.legend(loc=loss_legend_loc)
    plt.title('Training and Validation Loss')
        
    plt.subplot(sub_plot2[0], sub_plot2[1], sub_plot2[2])
    
    for i in range(len(train_acc)):
        x_train = range(len(train_acc[i]))
        x_val = range(len(val_acc[i]))
        
        max_train_acc = train_acc[i].max() 
        
        max_val_acc = val_acc[i].max() 
        
        plt.plot(x_train, train_acc[i], linestyle='-', color='tab:{}'.format(colors[i]), 
                 label="TRAIN ACC ({0:.4})".format(max_train_acc))
        plt.plot(x_val, val_acc[i], linestyle='--' , color='tab:{}'.format(colors[i]), 
                 label="VALID ACC ({0:.4})".format(max_val_acc))
        
    plt.xlabel('epoch no.')
    plt.ylabel('accuracy')
    plt.legend(loc=acc_legend_loc)
    plt.title('Training and Validation Accuracy')
    
    fig.savefig('sample_loss_acc_plot.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:red">4.8. Define Model [20 Points]</font>
#
# In the section, you will define the CNN model. You need to keep iterating by training various models by changing:
#     - Number of layers
#     - Parameters inside the layers
#     - different types of layers

# %%
class MyModel(nn.Module):
#     YOUR CODE HERE
    def __init__(self):
        super().__init__()

        ###
        # convolution layers
        self._body = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=7),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),            

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2),
            
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2)
        )

        
        # Fully connected layers
        self._head = nn.Sequential(
            nn.Linear(in_features=256*12*12, out_features=4096), 
            nn.ReLU(inplace=True), 
            nn.Dropout(0.6),            
            nn.Linear(in_features=4096, out_features=1024), 
            nn.ReLU(inplace=True), 
            nn.Dropout(0.4),
            nn.Linear(in_features=1024, out_features=3),             
        )
    
    def forward(self, x):
        
        # apply feature extractor
        x = self._body(x)
        # flatten the output of conv layers
        # dimension should be batch_size * number_of weight_in_last conv_layer
        x = x.view(x.size()[0], -1)
        # apply classification head
        x = self._head(x)
        
        
        return x

# %% [markdown]
# ## <font style="color:red">4.9. Training [20 Points]</font>
# You should experiment with
#     - Optimizers and learning rate schedulers [You can even get good results without a learning rate shceduler]
#     - Regularization techniques like Data Augmentation, Dropout, BatchNorm

# %%
model = MyModel()
print(model)

# get optimizer
train_config = TrainingConfiguration()

### CHANGE HERE ###

# optimizer
optimizer = optim.Adam(
    model.parameters(),
    lr = train_config.init_learning_rate
)

scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=0.95)
# Out:
# MyModel(
#   (_body): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU(inplace=True)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (_head): Sequential(
#     (0): Linear(in_features=36864, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.6, inplace=False)
#     (3): Linear(in_features=4096, out_features=1024, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=1024, out_features=3, bias=True)
#   )
# )

# %%
# train and validate
model, train_loss, train_acc, val_loss, val_acc = main(model, optimizer, scheduler=None, data_augmentation=True)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])
#
# Test set: Average loss: 1.0984, Accuracy: 200/600 (33%)
#
# Initial Test Loss : 1.098389,
# Initial Test Accuracy : 33.333%
#
# Epoch: 0
# Train Loss: 4.926238 Acc: 0.3754
# Elapsed 31.50s, 31.50 s/epoch, 0.42 s/batch, ets 12568.13s
#
# Test set: Average loss: 1.0027, Accuracy: 290/600 (48%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 1.0027, Accuracy: 290/600 (48%)
#
# Initial Test Loss : 1.002654,
# Initial Test Accuracy : 48.333%
#
# Epoch: 1
# Train Loss: 1.046978 Acc: 0.4596
# Elapsed 70.64s, 35.32 s/epoch, 0.47 s/batch, ets 14057.47s
#
# Test set: Average loss: 0.9179, Accuracy: 329/600 (55%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.9179, Accuracy: 329/600 (55%)
#
# Initial Test Loss : 0.917918,
# Initial Test Accuracy : 54.833%
#
# Epoch: 2
# Train Loss: 1.011044 Acc: 0.4658
# Elapsed 109.79s, 36.60 s/epoch, 0.49 s/batch, ets 14529.48s
#
# Test set: Average loss: 1.3146, Accuracy: 232/600 (39%)
#
#
# Test set: Average loss: 1.3146, Accuracy: 232/600 (39%)
#
# Initial Test Loss : 1.314608,
# Initial Test Accuracy : 38.667%
#
# Epoch: 3
# Train Loss: 1.010112 Acc: 0.4808
# Elapsed 143.48s, 35.87 s/epoch, 0.48 s/batch, ets 14204.32s
#
# Test set: Average loss: 0.9006, Accuracy: 310/600 (52%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.9006, Accuracy: 310/600 (52%)
#
# Initial Test Loss : 0.900640,
# Initial Test Accuracy : 51.667%
#
# Epoch: 4
# Train Loss: 0.998845 Acc: 0.4900
# Elapsed 183.78s, 36.76 s/epoch, 0.49 s/batch, ets 14518.53s
#
# Test set: Average loss: 0.9443, Accuracy: 311/600 (52%)
#
#
# Test set: Average loss: 0.9443, Accuracy: 311/600 (52%)
#
# Initial Test Loss : 0.944262,
# Initial Test Accuracy : 51.833%
#
# Epoch: 5
# Train Loss: 1.012049 Acc: 0.4913
# Elapsed 217.51s, 36.25 s/epoch, 0.48 s/batch, ets 14283.27s
#
# Test set: Average loss: 0.8777, Accuracy: 332/600 (55%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.8777, Accuracy: 332/600 (55%)
#
# Initial Test Loss : 0.877726,
# Initial Test Accuracy : 55.333%
#
# Epoch: 6
# Train Loss: 0.984067 Acc: 0.4983
# Elapsed 259.22s, 37.03 s/epoch, 0.49 s/batch, ets 14553.47s
#
# Test set: Average loss: 0.9268, Accuracy: 323/600 (54%)
#
#
# Test set: Average loss: 0.9268, Accuracy: 323/600 (54%)
#
# Initial Test Loss : 0.926800,
# Initial Test Accuracy : 53.833%
#
# Epoch: 7
# Train Loss: 0.995144 Acc: 0.5046
# Elapsed 293.05s, 36.63 s/epoch, 0.49 s/batch, ets 14359.49s
#
# Test set: Average loss: 0.9045, Accuracy: 350/600 (58%)
#
#
# Test set: Average loss: 0.9045, Accuracy: 350/600 (58%)
#
# Initial Test Loss : 0.904490,
# Initial Test Accuracy : 58.333%
#
# Epoch: 8
# Train Loss: 0.980913 Acc: 0.4963
# Elapsed 326.84s, 36.32 s/epoch, 0.48 s/batch, ets 14199.33s
#
# Test set: Average loss: 0.8831, Accuracy: 321/600 (54%)
#
#
# Test set: Average loss: 0.8831, Accuracy: 321/600 (54%)
#
# Initial Test Loss : 0.883110,
# Initial Test Accuracy : 53.500%
#
# Epoch: 9
# Train Loss: 0.985654 Acc: 0.4829
# Elapsed 360.67s, 36.07 s/epoch, 0.48 s/batch, ets 14066.04s
#
# Test set: Average loss: 0.9329, Accuracy: 322/600 (54%)
#
#
# Test set: Average loss: 0.9329, Accuracy: 322/600 (54%)
#
# Initial Test Loss : 0.932861,
# Initial Test Accuracy : 53.667%
#
# Epoch: 10
# Train Loss: 0.972100 Acc: 0.5129
# Elapsed 394.57s, 35.87 s/epoch, 0.48 s/batch, ets 13953.29s
#
# Test set: Average loss: 0.9037, Accuracy: 332/600 (55%)
#
#
# Test set: Average loss: 0.9037, Accuracy: 332/600 (55%)
#
# Initial Test Loss : 0.903654,
# Initial Test Accuracy : 55.333%
#
# Epoch: 11
# Train Loss: 0.997477 Acc: 0.4900
# Elapsed 428.60s, 35.72 s/epoch, 0.48 s/batch, ets 13858.12s
#
# Test set: Average loss: 0.9718, Accuracy: 315/600 (52%)
#
#
# Test set: Average loss: 0.9718, Accuracy: 315/600 (52%)
#
# Initial Test Loss : 0.971760,
# Initial Test Accuracy : 52.500%
#
# Epoch: 12
# Train Loss: 1.003484 Acc: 0.5100
# Elapsed 462.68s, 35.59 s/epoch, 0.47 s/batch, ets 13773.51s
#
# Test set: Average loss: 0.8539, Accuracy: 340/600 (57%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.8539, Accuracy: 340/600 (57%)
#
# Initial Test Loss : 0.853931,
# Initial Test Accuracy : 56.667%
#
# Epoch: 13
# Train Loss: 0.984745 Acc: 0.5075
# Elapsed 504.22s, 36.02 s/epoch, 0.48 s/batch, ets 13902.06s
#
# Test set: Average loss: 0.8997, Accuracy: 335/600 (56%)
#
#
# Test set: Average loss: 0.8997, Accuracy: 335/600 (56%)
#
# Initial Test Loss : 0.899739,
# Initial Test Accuracy : 55.833%
#
# Epoch: 14
# Train Loss: 0.997232 Acc: 0.4904
# Elapsed 538.34s, 35.89 s/epoch, 0.48 s/batch, ets 13817.46s
#
# Test set: Average loss: 0.9449, Accuracy: 338/600 (56%)
#
#
# Test set: Average loss: 0.9449, Accuracy: 338/600 (56%)
#
# Initial Test Loss : 0.944876,
# Initial Test Accuracy : 56.333%
#
# Epoch: 15
# Train Loss: 0.992560 Acc: 0.4838
# Elapsed 572.48s, 35.78 s/epoch, 0.48 s/batch, ets 13739.53s
#
# Test set: Average loss: 0.9266, Accuracy: 330/600 (55%)
#
#
# Test set: Average loss: 0.9266, Accuracy: 330/600 (55%)
#
# Initial Test Loss : 0.926568,
# Initial Test Accuracy : 55.000%
#
# Epoch: 16
# Train Loss: 0.971604 Acc: 0.4863
# Elapsed 606.55s, 35.68 s/epoch, 0.48 s/batch, ets 13665.31s
#
# Test set: Average loss: 0.9138, Accuracy: 349/600 (58%)
#
#
# Test set: Average loss: 0.9138, Accuracy: 349/600 (58%)
#
# Initial Test Loss : 0.913848,
# Initial Test Accuracy : 58.167%
#
# Epoch: 17
# Train Loss: 0.969975 Acc: 0.4796
# Elapsed 640.65s, 35.59 s/epoch, 0.47 s/batch, ets 13595.98s
#
# Test set: Average loss: 0.8938, Accuracy: 379/600 (63%)
#
#
# Test set: Average loss: 0.8938, Accuracy: 379/600 (63%)
#
# Initial Test Loss : 0.893845,
# Initial Test Accuracy : 63.167%
#
# Epoch: 18
# Train Loss: 0.963370 Acc: 0.5088
# Elapsed 674.71s, 35.51 s/epoch, 0.47 s/batch, ets 13529.77s
#
# Test set: Average loss: 0.9343, Accuracy: 350/600 (58%)
#
#
# Test set: Average loss: 0.9343, Accuracy: 350/600 (58%)
#
# Initial Test Loss : 0.934349,
# Initial Test Accuracy : 58.333%
#
# Epoch: 19
# Train Loss: 0.956392 Acc: 0.5067
# Elapsed 708.76s, 35.44 s/epoch, 0.47 s/batch, ets 13466.42s
#
# Test set: Average loss: 0.9121, Accuracy: 284/600 (47%)
#
#
# Test set: Average loss: 0.9121, Accuracy: 284/600 (47%)
#
# Initial Test Loss : 0.912077,
# Initial Test Accuracy : 47.333%
#
# Epoch: 20
# Train Loss: 0.947345 Acc: 0.5096
# Elapsed 742.93s, 35.38 s/epoch, 0.47 s/batch, ets 13408.09s
#
# Test set: Average loss: 0.8977, Accuracy: 296/600 (49%)
#
#
# Test set: Average loss: 0.8977, Accuracy: 296/600 (49%)
#
# Initial Test Loss : 0.897750,
# Initial Test Accuracy : 49.333%
#
# Epoch: 21
# Train Loss: 0.928607 Acc: 0.5329
# Elapsed 777.00s, 35.32 s/epoch, 0.47 s/batch, ets 13350.24s
#
# Test set: Average loss: 0.8996, Accuracy: 343/600 (57%)
#
#
# Test set: Average loss: 0.8996, Accuracy: 343/600 (57%)
#
# Initial Test Loss : 0.899584,
# Initial Test Accuracy : 57.167%
#
# Epoch: 22
# Train Loss: 0.938845 Acc: 0.5175
# Elapsed 811.17s, 35.27 s/epoch, 0.47 s/batch, ets 13296.08s
#
# Test set: Average loss: 0.8562, Accuracy: 359/600 (60%)
#
#
# Test set: Average loss: 0.8562, Accuracy: 359/600 (60%)
#
# Initial Test Loss : 0.856162,
# Initial Test Accuracy : 59.833%
#
# Epoch: 23
# Train Loss: 0.920640 Acc: 0.5262
# Elapsed 845.37s, 35.22 s/epoch, 0.47 s/batch, ets 13244.19s
#
# Test set: Average loss: 0.8285, Accuracy: 345/600 (58%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.8285, Accuracy: 345/600 (58%)
#
# Initial Test Loss : 0.828548,
# Initial Test Accuracy : 57.500%
#
# Epoch: 24
# Train Loss: 0.926213 Acc: 0.5217
# Elapsed 887.26s, 35.49 s/epoch, 0.47 s/batch, ets 13308.92s
#
# Test set: Average loss: 0.8331, Accuracy: 355/600 (59%)
#
#
# Test set: Average loss: 0.8331, Accuracy: 355/600 (59%)
#
# Initial Test Loss : 0.833094,
# Initial Test Accuracy : 59.167%
#
# Epoch: 25
# Train Loss: 0.899906 Acc: 0.5458
# Elapsed 921.45s, 35.44 s/epoch, 0.47 s/batch, ets 13254.71s
#
# Test set: Average loss: 0.9071, Accuracy: 328/600 (55%)
#
#
# Test set: Average loss: 0.9071, Accuracy: 328/600 (55%)
#
# Initial Test Loss : 0.907060,
# Initial Test Accuracy : 54.667%
#
# Epoch: 26
# Train Loss: 0.950522 Acc: 0.5312
# Elapsed 955.61s, 35.39 s/epoch, 0.47 s/batch, ets 13201.55s
#
# Test set: Average loss: 0.9291, Accuracy: 373/600 (62%)
#
#
# Test set: Average loss: 0.9291, Accuracy: 373/600 (62%)
#
# Initial Test Loss : 0.929070,
# Initial Test Accuracy : 62.167%
#
# Epoch: 27
# Train Loss: 0.916928 Acc: 0.5333
# Elapsed 989.72s, 35.35 s/epoch, 0.47 s/batch, ets 13149.08s
#
# Test set: Average loss: 0.8352, Accuracy: 339/600 (56%)
#
#
# Test set: Average loss: 0.8352, Accuracy: 339/600 (56%)
#
# Initial Test Loss : 0.835214,
# Initial Test Accuracy : 56.500%
#
# Epoch: 28
# Train Loss: 0.947932 Acc: 0.5250
# Elapsed 1023.73s, 35.30 s/epoch, 0.47 s/batch, ets 13096.69s
#
# Test set: Average loss: 0.8101, Accuracy: 314/600 (52%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.8101, Accuracy: 314/600 (52%)
#
# Initial Test Loss : 0.810061,
# Initial Test Accuracy : 52.333%
#
# Epoch: 29
# Train Loss: 0.903414 Acc: 0.5333
# Elapsed 1065.31s, 35.51 s/epoch, 0.47 s/batch, ets 13138.85s
#
# Test set: Average loss: 0.8245, Accuracy: 328/600 (55%)
#
#
# Test set: Average loss: 0.8245, Accuracy: 328/600 (55%)
#
# Initial Test Loss : 0.824512,
# Initial Test Accuracy : 54.667%
#
# Epoch: 30
# Train Loss: 0.899372 Acc: 0.5233
# Elapsed 1099.41s, 35.46 s/epoch, 0.47 s/batch, ets 13086.55s
#
# Test set: Average loss: 0.9076, Accuracy: 348/600 (58%)
#
#
# Test set: Average loss: 0.9076, Accuracy: 348/600 (58%)
#
# Initial Test Loss : 0.907628,
# Initial Test Accuracy : 58.000%
#
# Epoch: 31
# Train Loss: 0.908908 Acc: 0.5317
# Elapsed 1133.48s, 35.42 s/epoch, 0.47 s/batch, ets 13035.05s
#
# Test set: Average loss: 0.9047, Accuracy: 305/600 (51%)
#
#
# Test set: Average loss: 0.9047, Accuracy: 305/600 (51%)
#
# Initial Test Loss : 0.904705,
# Initial Test Accuracy : 50.833%
#
# Epoch: 32
# Train Loss: 0.919542 Acc: 0.5212
# Elapsed 1167.53s, 35.38 s/epoch, 0.47 s/batch, ets 12984.30s
#
# Test set: Average loss: 0.8980, Accuracy: 337/600 (56%)
#
#
# Test set: Average loss: 0.8980, Accuracy: 337/600 (56%)
#
# Initial Test Loss : 0.897953,
# Initial Test Accuracy : 56.167%
#
# Epoch: 33
# Train Loss: 0.900350 Acc: 0.5458
# Elapsed 1201.58s, 35.34 s/epoch, 0.47 s/batch, ets 12934.66s
#
# Test set: Average loss: 0.9159, Accuracy: 335/600 (56%)
#
#
# Test set: Average loss: 0.9159, Accuracy: 335/600 (56%)
#
# Initial Test Loss : 0.915867,
# Initial Test Accuracy : 55.833%
#
# Epoch: 34
# Train Loss: 0.898896 Acc: 0.5379
# Elapsed 1235.64s, 35.30 s/epoch, 0.47 s/batch, ets 12885.98s
#
# Test set: Average loss: 0.8940, Accuracy: 346/600 (58%)
#
#
# Test set: Average loss: 0.8940, Accuracy: 346/600 (58%)
#
# Initial Test Loss : 0.894047,
# Initial Test Accuracy : 57.667%
#
# Epoch: 35
# Train Loss: 0.906798 Acc: 0.5463
# Elapsed 1269.66s, 35.27 s/epoch, 0.47 s/batch, ets 12837.66s
#
# Test set: Average loss: 0.8801, Accuracy: 358/600 (60%)
#
#
# Test set: Average loss: 0.8801, Accuracy: 358/600 (60%)
#
# Initial Test Loss : 0.880140,
# Initial Test Accuracy : 59.667%
#
# Epoch: 36
# Train Loss: 0.899490 Acc: 0.5467
# Elapsed 1303.72s, 35.24 s/epoch, 0.47 s/batch, ets 12790.60s
#
# Test set: Average loss: 0.9123, Accuracy: 357/600 (60%)
#
#
# Test set: Average loss: 0.9123, Accuracy: 357/600 (60%)
#
# Initial Test Loss : 0.912285,
# Initial Test Accuracy : 59.500%
#
# Epoch: 37
# Train Loss: 0.888205 Acc: 0.5329
# Elapsed 1337.81s, 35.21 s/epoch, 0.47 s/batch, ets 12744.42s
#
# Test set: Average loss: 0.8882, Accuracy: 372/600 (62%)
#
#
# Test set: Average loss: 0.8882, Accuracy: 372/600 (62%)
#
# Initial Test Loss : 0.888155,
# Initial Test Accuracy : 62.000%
#
# Epoch: 38
# Train Loss: 0.900539 Acc: 0.5246
# Elapsed 1371.89s, 35.18 s/epoch, 0.47 s/batch, ets 12698.76s
#
# Test set: Average loss: 0.8246, Accuracy: 328/600 (55%)
#
#
# Test set: Average loss: 0.8246, Accuracy: 328/600 (55%)
#
# Initial Test Loss : 0.824595,
# Initial Test Accuracy : 54.667%
#
# Epoch: 39
# Train Loss: 0.896283 Acc: 0.5308
# Elapsed 1405.97s, 35.15 s/epoch, 0.47 s/batch, ets 12653.72s
#
# Test set: Average loss: 0.8274, Accuracy: 362/600 (60%)
#
#
# Test set: Average loss: 0.8274, Accuracy: 362/600 (60%)
#
# Initial Test Loss : 0.827433,
# Initial Test Accuracy : 60.333%
#
# Epoch: 40
# Train Loss: 0.886773 Acc: 0.5350
# Elapsed 1440.11s, 35.12 s/epoch, 0.47 s/batch, ets 12609.73s
#
# Test set: Average loss: 0.8010, Accuracy: 352/600 (59%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.8010, Accuracy: 352/600 (59%)
#
# Initial Test Loss : 0.800980,
# Initial Test Accuracy : 58.667%
#
# Epoch: 41
# Train Loss: 0.840251 Acc: 0.5575
# Elapsed 1481.87s, 35.28 s/epoch, 0.47 s/batch, ets 12631.20s
#
# Test set: Average loss: 0.8173, Accuracy: 333/600 (56%)
#
#
# Test set: Average loss: 0.8173, Accuracy: 333/600 (56%)
#
# Initial Test Loss : 0.817344,
# Initial Test Accuracy : 55.500%
#
# Epoch: 42
# Train Loss: 0.871126 Acc: 0.5592
# Elapsed 1515.93s, 35.25 s/epoch, 0.47 s/batch, ets 12585.73s
#
# Test set: Average loss: 0.8230, Accuracy: 355/600 (59%)
#
#
# Test set: Average loss: 0.8230, Accuracy: 355/600 (59%)
#
# Initial Test Loss : 0.822972,
# Initial Test Accuracy : 59.167%
#
# Epoch: 43
# Train Loss: 0.847117 Acc: 0.5563
# Elapsed 1549.95s, 35.23 s/epoch, 0.47 s/batch, ets 12540.49s
#
# Test set: Average loss: 0.8325, Accuracy: 353/600 (59%)
#
#
# Test set: Average loss: 0.8325, Accuracy: 353/600 (59%)
#
# Initial Test Loss : 0.832528,
# Initial Test Accuracy : 58.833%
#
# Epoch: 44
# Train Loss: 0.850816 Acc: 0.5483
# Elapsed 1584.09s, 35.20 s/epoch, 0.47 s/batch, ets 12496.73s
#
# Test set: Average loss: 0.8246, Accuracy: 359/600 (60%)
#
#
# Test set: Average loss: 0.8246, Accuracy: 359/600 (60%)
#
# Initial Test Loss : 0.824561,
# Initial Test Accuracy : 59.833%
#
# Epoch: 45
# Train Loss: 0.851447 Acc: 0.5421
# Elapsed 1618.26s, 35.18 s/epoch, 0.47 s/batch, ets 12453.59s
#
# Test set: Average loss: 0.7830, Accuracy: 353/600 (59%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.7830, Accuracy: 353/600 (59%)
#
# Initial Test Loss : 0.782968,
# Initial Test Accuracy : 58.833%
#
# Epoch: 46
# Train Loss: 0.857104 Acc: 0.5850
# Elapsed 1657.22s, 35.26 s/epoch, 0.47 s/batch, ets 12446.79s
#
# Test set: Average loss: 0.7912, Accuracy: 352/600 (59%)
#
#
# Test set: Average loss: 0.7912, Accuracy: 352/600 (59%)
#
# Initial Test Loss : 0.791173,
# Initial Test Accuracy : 58.667%
#
# Epoch: 47
# Train Loss: 0.854014 Acc: 0.5925
# Elapsed 1691.25s, 35.23 s/epoch, 0.47 s/batch, ets 12402.50s
#
# Test set: Average loss: 0.7594, Accuracy: 369/600 (62%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.7594, Accuracy: 369/600 (62%)
#
# Initial Test Loss : 0.759351,
# Initial Test Accuracy : 61.500%
#
# Epoch: 48
# Train Loss: 0.888910 Acc: 0.5683
# Elapsed 1730.69s, 35.32 s/epoch, 0.47 s/batch, ets 12397.37s
#
# Test set: Average loss: 0.7894, Accuracy: 365/600 (61%)
#
#
# Test set: Average loss: 0.7894, Accuracy: 365/600 (61%)
#
# Initial Test Loss : 0.789369,
# Initial Test Accuracy : 60.833%
#
# Epoch: 49
# Train Loss: 0.858575 Acc: 0.5654
# Elapsed 1764.73s, 35.29 s/epoch, 0.47 s/batch, ets 12353.13s
#
# Test set: Average loss: 0.7239, Accuracy: 357/600 (60%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.7239, Accuracy: 357/600 (60%)
#
# Initial Test Loss : 0.723932,
# Initial Test Accuracy : 59.500%
#
# Epoch: 50
# Train Loss: 0.858766 Acc: 0.5733
# Elapsed 1806.19s, 35.42 s/epoch, 0.47 s/batch, ets 12360.03s
#
# Test set: Average loss: 0.8113, Accuracy: 362/600 (60%)
#
#
# Test set: Average loss: 0.8113, Accuracy: 362/600 (60%)
#
# Initial Test Loss : 0.811275,
# Initial Test Accuracy : 60.333%
#
# Epoch: 51
# Train Loss: 0.876803 Acc: 0.5767
# Elapsed 1840.18s, 35.39 s/epoch, 0.47 s/batch, ets 12315.07s
#
# Test set: Average loss: 0.8202, Accuracy: 354/600 (59%)
#
#
# Test set: Average loss: 0.8202, Accuracy: 354/600 (59%)
#
# Initial Test Loss : 0.820180,
# Initial Test Accuracy : 59.000%
#
# Epoch: 52
# Train Loss: 0.865001 Acc: 0.5779
# Elapsed 1874.19s, 35.36 s/epoch, 0.47 s/batch, ets 12270.67s
#
# Test set: Average loss: 0.7750, Accuracy: 339/600 (56%)
#
#
# Test set: Average loss: 0.7750, Accuracy: 339/600 (56%)
#
# Initial Test Loss : 0.774959,
# Initial Test Accuracy : 56.500%
#
# Epoch: 53
# Train Loss: 0.848223 Acc: 0.5771
# Elapsed 1908.10s, 35.34 s/epoch, 0.47 s/batch, ets 12225.98s
#
# Test set: Average loss: 0.7576, Accuracy: 384/600 (64%)
#
#
# Test set: Average loss: 0.7576, Accuracy: 384/600 (64%)
#
# Initial Test Loss : 0.757627,
# Initial Test Accuracy : 64.000%
#
# Epoch: 54
# Train Loss: 0.838977 Acc: 0.5867
# Elapsed 1942.18s, 35.31 s/epoch, 0.47 s/batch, ets 12182.75s
#
# Test set: Average loss: 0.7637, Accuracy: 380/600 (63%)
#
#
# Test set: Average loss: 0.7637, Accuracy: 380/600 (63%)
#
# Initial Test Loss : 0.763660,
# Initial Test Accuracy : 63.333%
#
# Epoch: 55
# Train Loss: 0.814403 Acc: 0.5938
# Elapsed 1976.16s, 35.29 s/epoch, 0.47 s/batch, ets 12139.27s
#
# Test set: Average loss: 0.7260, Accuracy: 376/600 (63%)
#
#
# Test set: Average loss: 0.7260, Accuracy: 376/600 (63%)
#
# Initial Test Loss : 0.726001,
# Initial Test Accuracy : 62.667%
#
# Epoch: 56
# Train Loss: 0.846044 Acc: 0.5708
# Elapsed 2010.20s, 35.27 s/epoch, 0.47 s/batch, ets 12096.44s
#
# Test set: Average loss: 0.7092, Accuracy: 381/600 (64%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.7092, Accuracy: 381/600 (64%)
#
# Initial Test Loss : 0.709214,
# Initial Test Accuracy : 63.500%
#
# Epoch: 57
# Train Loss: 0.822942 Acc: 0.5908
# Elapsed 2053.04s, 35.40 s/epoch, 0.47 s/batch, ets 12105.86s
#
# Test set: Average loss: 0.7397, Accuracy: 381/600 (64%)
#
#
# Test set: Average loss: 0.7397, Accuracy: 381/600 (64%)
#
# Initial Test Loss : 0.739720,
# Initial Test Accuracy : 63.500%
#
# Epoch: 58
# Train Loss: 0.811001 Acc: 0.5917
# Elapsed 2087.02s, 35.37 s/epoch, 0.47 s/batch, ets 12062.29s
#
# Test set: Average loss: 0.7996, Accuracy: 361/600 (60%)
#
#
# Test set: Average loss: 0.7996, Accuracy: 361/600 (60%)
#
# Initial Test Loss : 0.799612,
# Initial Test Accuracy : 60.167%
#
# Epoch: 59
# Train Loss: 0.802843 Acc: 0.6125
# Elapsed 2121.10s, 35.35 s/epoch, 0.47 s/batch, ets 12019.57s
#
# Test set: Average loss: 0.6942, Accuracy: 397/600 (66%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6942, Accuracy: 397/600 (66%)
#
# Initial Test Loss : 0.694237,
# Initial Test Accuracy : 66.167%
#
# Epoch: 60
# Train Loss: 0.805579 Acc: 0.5983
# Elapsed 2160.79s, 35.42 s/epoch, 0.47 s/batch, ets 12008.31s
#
# Test set: Average loss: 0.6855, Accuracy: 410/600 (68%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6855, Accuracy: 410/600 (68%)
#
# Initial Test Loss : 0.685521,
# Initial Test Accuracy : 68.333%
#
# Epoch: 61
# Train Loss: 0.775140 Acc: 0.6175
# Elapsed 2201.68s, 35.51 s/epoch, 0.47 s/batch, ets 12002.69s
#
# Test set: Average loss: 0.7482, Accuracy: 383/600 (64%)
#
#
# Test set: Average loss: 0.7482, Accuracy: 383/600 (64%)
#
# Initial Test Loss : 0.748248,
# Initial Test Accuracy : 63.833%
#
# Epoch: 62
# Train Loss: 0.764805 Acc: 0.6325
# Elapsed 2235.70s, 35.49 s/epoch, 0.47 s/batch, ets 11959.24s
#
# Test set: Average loss: 0.7125, Accuracy: 399/600 (66%)
#
#
# Test set: Average loss: 0.7125, Accuracy: 399/600 (66%)
#
# Initial Test Loss : 0.712486,
# Initial Test Accuracy : 66.500%
#
# Epoch: 63
# Train Loss: 0.790454 Acc: 0.6029
# Elapsed 2269.72s, 35.46 s/epoch, 0.47 s/batch, ets 11916.01s
#
# Test set: Average loss: 0.7195, Accuracy: 387/600 (64%)
#
#
# Test set: Average loss: 0.7195, Accuracy: 387/600 (64%)
#
# Initial Test Loss : 0.719486,
# Initial Test Accuracy : 64.500%
#
# Epoch: 64
# Train Loss: 0.798347 Acc: 0.6054
# Elapsed 2303.72s, 35.44 s/epoch, 0.47 s/batch, ets 11873.03s
#
# Test set: Average loss: 0.9080, Accuracy: 346/600 (58%)
#
#
# Test set: Average loss: 0.9080, Accuracy: 346/600 (58%)
#
# Initial Test Loss : 0.908011,
# Initial Test Accuracy : 57.667%
#
# Epoch: 65
# Train Loss: 0.794371 Acc: 0.6158
# Elapsed 2337.72s, 35.42 s/epoch, 0.47 s/batch, ets 11830.28s
#
# Test set: Average loss: 0.6885, Accuracy: 392/600 (65%)
#
#
# Test set: Average loss: 0.6885, Accuracy: 392/600 (65%)
#
# Initial Test Loss : 0.688509,
# Initial Test Accuracy : 65.333%
#
# Epoch: 66
# Train Loss: 0.772708 Acc: 0.6121
# Elapsed 2371.79s, 35.40 s/epoch, 0.47 s/batch, ets 11788.16s
#
# Test set: Average loss: 0.6815, Accuracy: 398/600 (66%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6815, Accuracy: 398/600 (66%)
#
# Initial Test Loss : 0.681483,
# Initial Test Accuracy : 66.333%
#
# Epoch: 67
# Train Loss: 0.801639 Acc: 0.5962
# Elapsed 2413.29s, 35.49 s/epoch, 0.47 s/batch, ets 11782.54s
#
# Test set: Average loss: 0.7149, Accuracy: 397/600 (66%)
#
#
# Test set: Average loss: 0.7149, Accuracy: 397/600 (66%)
#
# Initial Test Loss : 0.714863,
# Initial Test Accuracy : 66.167%
#
# Epoch: 68
# Train Loss: 0.767001 Acc: 0.6179
# Elapsed 2447.39s, 35.47 s/epoch, 0.47 s/batch, ets 11740.39s
#
# Test set: Average loss: 0.6823, Accuracy: 400/600 (67%)
#
#
# Test set: Average loss: 0.6823, Accuracy: 400/600 (67%)
#
# Initial Test Loss : 0.682320,
# Initial Test Accuracy : 66.667%
#
# Epoch: 69
# Train Loss: 0.759790 Acc: 0.6312
# Elapsed 2481.41s, 35.45 s/epoch, 0.47 s/batch, ets 11698.09s
#
# Test set: Average loss: 0.6767, Accuracy: 404/600 (67%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6767, Accuracy: 404/600 (67%)
#
# Initial Test Loss : 0.676695,
# Initial Test Accuracy : 67.333%
#
# Epoch: 70
# Train Loss: 0.778761 Acc: 0.6229
# Elapsed 2522.73s, 35.53 s/epoch, 0.47 s/batch, ets 11689.81s
#
# Test set: Average loss: 0.7202, Accuracy: 380/600 (63%)
#
#
# Test set: Average loss: 0.7202, Accuracy: 380/600 (63%)
#
# Initial Test Loss : 0.720182,
# Initial Test Accuracy : 63.333%
#
# Epoch: 71
# Train Loss: 0.769729 Acc: 0.6146
# Elapsed 2556.71s, 35.51 s/epoch, 0.47 s/batch, ets 11647.23s
#
# Test set: Average loss: 0.6900, Accuracy: 396/600 (66%)
#
#
# Test set: Average loss: 0.6900, Accuracy: 396/600 (66%)
#
# Initial Test Loss : 0.689956,
# Initial Test Accuracy : 66.000%
#
# Epoch: 72
# Train Loss: 0.766867 Acc: 0.6267
# Elapsed 2590.79s, 35.49 s/epoch, 0.47 s/batch, ets 11605.30s
#
# Test set: Average loss: 0.7495, Accuracy: 380/600 (63%)
#
#
# Test set: Average loss: 0.7495, Accuracy: 380/600 (63%)
#
# Initial Test Loss : 0.749500,
# Initial Test Accuracy : 63.333%
#
# Epoch: 73
# Train Loss: 0.756069 Acc: 0.6242
# Elapsed 2624.74s, 35.47 s/epoch, 0.47 s/batch, ets 11563.06s
#
# Test set: Average loss: 0.6857, Accuracy: 386/600 (64%)
#
#
# Test set: Average loss: 0.6857, Accuracy: 386/600 (64%)
#
# Initial Test Loss : 0.685652,
# Initial Test Accuracy : 64.333%
#
# Epoch: 74
# Train Loss: 0.737901 Acc: 0.6346
# Elapsed 2658.81s, 35.45 s/epoch, 0.47 s/batch, ets 11521.51s
#
# Test set: Average loss: 0.6611, Accuracy: 419/600 (70%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6611, Accuracy: 419/600 (70%)
#
# Initial Test Loss : 0.661069,
# Initial Test Accuracy : 69.833%
#
# Epoch: 75
# Train Loss: 0.750319 Acc: 0.6325
# Elapsed 2700.81s, 35.54 s/epoch, 0.47 s/batch, ets 11513.99s
#
# Test set: Average loss: 0.6892, Accuracy: 401/600 (67%)
#
#
# Test set: Average loss: 0.6892, Accuracy: 401/600 (67%)
#
# Initial Test Loss : 0.689185,
# Initial Test Accuracy : 66.833%
#
# Epoch: 76
# Train Loss: 0.751424 Acc: 0.6233
# Elapsed 2734.87s, 35.52 s/epoch, 0.47 s/batch, ets 11472.24s
#
# Test set: Average loss: 0.6925, Accuracy: 416/600 (69%)
#
#
# Test set: Average loss: 0.6925, Accuracy: 416/600 (69%)
#
# Initial Test Loss : 0.692460,
# Initial Test Accuracy : 69.333%
#
# Epoch: 77
# Train Loss: 0.751416 Acc: 0.6296
# Elapsed 2768.83s, 35.50 s/epoch, 0.47 s/batch, ets 11430.28s
#
# Test set: Average loss: 0.6450, Accuracy: 411/600 (68%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6450, Accuracy: 411/600 (68%)
#
# Initial Test Loss : 0.644960,
# Initial Test Accuracy : 68.500%
#
# Epoch: 78
# Train Loss: 0.748197 Acc: 0.6229
# Elapsed 2810.89s, 35.58 s/epoch, 0.47 s/batch, ets 11421.47s
#
# Test set: Average loss: 0.6540, Accuracy: 410/600 (68%)
#
#
# Test set: Average loss: 0.6540, Accuracy: 410/600 (68%)
#
# Initial Test Loss : 0.654006,
# Initial Test Accuracy : 68.333%
#
# Epoch: 79
# Train Loss: 0.735609 Acc: 0.6404
# Elapsed 2844.82s, 35.56 s/epoch, 0.47 s/batch, ets 11379.28s
#
# Test set: Average loss: 0.6666, Accuracy: 410/600 (68%)
#
#
# Test set: Average loss: 0.6666, Accuracy: 410/600 (68%)
#
# Initial Test Loss : 0.666625,
# Initial Test Accuracy : 68.333%
#
# Epoch: 80
# Train Loss: 0.722402 Acc: 0.6433
# Elapsed 2878.92s, 35.54 s/epoch, 0.47 s/batch, ets 11337.95s
#
# Test set: Average loss: 0.6093, Accuracy: 431/600 (72%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6093, Accuracy: 431/600 (72%)
#
# Initial Test Loss : 0.609327,
# Initial Test Accuracy : 71.833%
#
# Epoch: 81
# Train Loss: 0.725999 Acc: 0.6442
# Elapsed 2920.34s, 35.61 s/epoch, 0.47 s/batch, ets 11325.22s
#
# Test set: Average loss: 0.6492, Accuracy: 426/600 (71%)
#
#
# Test set: Average loss: 0.6492, Accuracy: 426/600 (71%)
#
# Initial Test Loss : 0.649154,
# Initial Test Accuracy : 71.000%
#
# Epoch: 82
# Train Loss: 0.732990 Acc: 0.6354
# Elapsed 2954.33s, 35.59 s/epoch, 0.47 s/batch, ets 11283.39s
#
# Test set: Average loss: 0.6640, Accuracy: 423/600 (70%)
#
#
# Test set: Average loss: 0.6640, Accuracy: 423/600 (70%)
#
# Initial Test Loss : 0.663996,
# Initial Test Accuracy : 70.500%
#
# Epoch: 83
# Train Loss: 0.732814 Acc: 0.6408
# Elapsed 2988.33s, 35.58 s/epoch, 0.47 s/batch, ets 11241.80s
#
# Test set: Average loss: 0.6257, Accuracy: 411/600 (68%)
#
#
# Test set: Average loss: 0.6257, Accuracy: 411/600 (68%)
#
# Initial Test Loss : 0.625715,
# Initial Test Accuracy : 68.500%
#
# Epoch: 84
# Train Loss: 0.726290 Acc: 0.6329
# Elapsed 3022.42s, 35.56 s/epoch, 0.47 s/batch, ets 11200.74s
#
# Test set: Average loss: 0.6445, Accuracy: 426/600 (71%)
#
#
# Test set: Average loss: 0.6445, Accuracy: 426/600 (71%)
#
# Initial Test Loss : 0.644516,
# Initial Test Accuracy : 71.000%
#
# Epoch: 85
# Train Loss: 0.711542 Acc: 0.6604
# Elapsed 3056.38s, 35.54 s/epoch, 0.47 s/batch, ets 11159.33s
#
# Test set: Average loss: 0.7130, Accuracy: 414/600 (69%)
#
#
# Test set: Average loss: 0.7130, Accuracy: 414/600 (69%)
#
# Initial Test Loss : 0.713014,
# Initial Test Accuracy : 69.000%
#
# Epoch: 86
# Train Loss: 0.718161 Acc: 0.6458
# Elapsed 3090.36s, 35.52 s/epoch, 0.47 s/batch, ets 11118.18s
#
# Test set: Average loss: 0.6320, Accuracy: 415/600 (69%)
#
#
# Test set: Average loss: 0.6320, Accuracy: 415/600 (69%)
#
# Initial Test Loss : 0.632010,
# Initial Test Accuracy : 69.167%
#
# Epoch: 87
# Train Loss: 0.721307 Acc: 0.6267
# Elapsed 3124.62s, 35.51 s/epoch, 0.47 s/batch, ets 11078.19s
#
# Test set: Average loss: 0.6368, Accuracy: 415/600 (69%)
#
#
# Test set: Average loss: 0.6368, Accuracy: 415/600 (69%)
#
# Initial Test Loss : 0.636833,
# Initial Test Accuracy : 69.167%
#
# Epoch: 88
# Train Loss: 0.711327 Acc: 0.6412
# Elapsed 3158.61s, 35.49 s/epoch, 0.47 s/batch, ets 11037.41s
#
# Test set: Average loss: 0.6293, Accuracy: 430/600 (72%)
#
#
# Test set: Average loss: 0.6293, Accuracy: 430/600 (72%)
#
# Initial Test Loss : 0.629269,
# Initial Test Accuracy : 71.667%
#
# Epoch: 89
# Train Loss: 0.710858 Acc: 0.6383
# Elapsed 3192.59s, 35.47 s/epoch, 0.47 s/batch, ets 10996.68s
#
# Test set: Average loss: 0.6263, Accuracy: 422/600 (70%)
#
#
# Test set: Average loss: 0.6263, Accuracy: 422/600 (70%)
#
# Initial Test Loss : 0.626255,
# Initial Test Accuracy : 70.333%
#
# Epoch: 90
# Train Loss: 0.731232 Acc: 0.6383
# Elapsed 3226.52s, 35.46 s/epoch, 0.47 s/batch, ets 10955.99s
#
# Test set: Average loss: 0.6132, Accuracy: 424/600 (71%)
#
#
# Test set: Average loss: 0.6132, Accuracy: 424/600 (71%)
#
# Initial Test Loss : 0.613190,
# Initial Test Accuracy : 70.667%
#
# Epoch: 91
# Train Loss: 0.703035 Acc: 0.6488
# Elapsed 3260.53s, 35.44 s/epoch, 0.47 s/batch, ets 10915.69s
#
# Test set: Average loss: 0.6002, Accuracy: 434/600 (72%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.6002, Accuracy: 434/600 (72%)
#
# Initial Test Loss : 0.600153,
# Initial Test Accuracy : 72.333%
#
# Epoch: 92
# Train Loss: 0.702469 Acc: 0.6512
# Elapsed 3302.11s, 35.51 s/epoch, 0.47 s/batch, ets 10900.50s
#
# Test set: Average loss: 0.6181, Accuracy: 421/600 (70%)
#
#
# Test set: Average loss: 0.6181, Accuracy: 421/600 (70%)
#
# Initial Test Loss : 0.618079,
# Initial Test Accuracy : 70.167%
#
# Epoch: 93
# Train Loss: 0.743699 Acc: 0.6329
# Elapsed 3336.11s, 35.49 s/epoch, 0.47 s/batch, ets 10860.09s
#
# Test set: Average loss: 0.6773, Accuracy: 406/600 (68%)
#
#
# Test set: Average loss: 0.6773, Accuracy: 406/600 (68%)
#
# Initial Test Loss : 0.677271,
# Initial Test Accuracy : 67.667%
#
# Epoch: 94
# Train Loss: 0.711408 Acc: 0.6433
# Elapsed 3370.15s, 35.48 s/epoch, 0.47 s/batch, ets 10819.95s
#
# Test set: Average loss: 0.6027, Accuracy: 424/600 (71%)
#
#
# Test set: Average loss: 0.6027, Accuracy: 424/600 (71%)
#
# Initial Test Loss : 0.602652,
# Initial Test Accuracy : 70.667%
#
# Epoch: 95
# Train Loss: 0.692096 Acc: 0.6658
# Elapsed 3404.11s, 35.46 s/epoch, 0.47 s/batch, ets 10779.69s
#
# Test set: Average loss: 0.6182, Accuracy: 431/600 (72%)
#
#
# Test set: Average loss: 0.6182, Accuracy: 431/600 (72%)
#
# Initial Test Loss : 0.618192,
# Initial Test Accuracy : 71.833%
#
# Epoch: 96
# Train Loss: 0.706210 Acc: 0.6425
# Elapsed 3438.09s, 35.44 s/epoch, 0.47 s/batch, ets 10739.61s
#
# Test set: Average loss: 0.6045, Accuracy: 425/600 (71%)
#
#
# Test set: Average loss: 0.6045, Accuracy: 425/600 (71%)
#
# Initial Test Loss : 0.604479,
# Initial Test Accuracy : 70.833%
#
# Epoch: 97
# Train Loss: 0.719994 Acc: 0.6362
# Elapsed 3472.13s, 35.43 s/epoch, 0.47 s/batch, ets 10699.84s
#
# Test set: Average loss: 0.6033, Accuracy: 434/600 (72%)
#
#
# Test set: Average loss: 0.6033, Accuracy: 434/600 (72%)
#
# Initial Test Loss : 0.603333,
# Initial Test Accuracy : 72.333%
#
# Epoch: 98
# Train Loss: 0.706078 Acc: 0.6554
# Elapsed 3506.15s, 35.42 s/epoch, 0.47 s/batch, ets 10660.10s
#
# Test set: Average loss: 0.5860, Accuracy: 436/600 (73%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5860, Accuracy: 436/600 (73%)
#
# Initial Test Loss : 0.586006,
# Initial Test Accuracy : 72.667%
#
# Epoch: 99
# Train Loss: 0.687797 Acc: 0.6679
# Elapsed 3548.06s, 35.48 s/epoch, 0.47 s/batch, ets 10644.17s
#
# Test set: Average loss: 0.6020, Accuracy: 437/600 (73%)
#
#
# Test set: Average loss: 0.6020, Accuracy: 437/600 (73%)
#
# Initial Test Loss : 0.601955,
# Initial Test Accuracy : 72.833%
#
# Epoch: 100
# Train Loss: 0.687010 Acc: 0.6621
# Elapsed 3582.06s, 35.47 s/epoch, 0.47 s/batch, ets 10604.31s
#
# Test set: Average loss: 0.5973, Accuracy: 438/600 (73%)
#
#
# Test set: Average loss: 0.5973, Accuracy: 438/600 (73%)
#
# Initial Test Loss : 0.597253,
# Initial Test Accuracy : 73.000%
#
# Epoch: 101
# Train Loss: 0.689904 Acc: 0.6637
# Elapsed 3616.09s, 35.45 s/epoch, 0.47 s/batch, ets 10564.64s
#
# Test set: Average loss: 0.7759, Accuracy: 403/600 (67%)
#
#
# Test set: Average loss: 0.7759, Accuracy: 403/600 (67%)
#
# Initial Test Loss : 0.775929,
# Initial Test Accuracy : 67.167%
#
# Epoch: 102
# Train Loss: 0.687245 Acc: 0.6750
# Elapsed 3650.12s, 35.44 s/epoch, 0.47 s/batch, ets 10525.10s
#
# Test set: Average loss: 0.6193, Accuracy: 428/600 (71%)
#
#
# Test set: Average loss: 0.6193, Accuracy: 428/600 (71%)
#
# Initial Test Loss : 0.619286,
# Initial Test Accuracy : 71.333%
#
# Epoch: 103
# Train Loss: 0.710336 Acc: 0.6567
# Elapsed 3684.10s, 35.42 s/epoch, 0.47 s/batch, ets 10485.51s
#
# Test set: Average loss: 0.6198, Accuracy: 431/600 (72%)
#
#
# Test set: Average loss: 0.6198, Accuracy: 431/600 (72%)
#
# Initial Test Loss : 0.619777,
# Initial Test Accuracy : 71.833%
#
# Epoch: 104
# Train Loss: 0.695912 Acc: 0.6600
# Elapsed 3718.13s, 35.41 s/epoch, 0.47 s/batch, ets 10446.18s
#
# Test set: Average loss: 0.6057, Accuracy: 423/600 (70%)
#
#
# Test set: Average loss: 0.6057, Accuracy: 423/600 (70%)
#
# Initial Test Loss : 0.605727,
# Initial Test Accuracy : 70.500%
#
# Epoch: 105
# Train Loss: 0.701902 Acc: 0.6629
# Elapsed 3752.13s, 35.40 s/epoch, 0.47 s/batch, ets 10406.86s
#
# Test set: Average loss: 0.6799, Accuracy: 412/600 (69%)
#
#
# Test set: Average loss: 0.6799, Accuracy: 412/600 (69%)
#
# Initial Test Loss : 0.679856,
# Initial Test Accuracy : 68.667%
#
# Epoch: 106
# Train Loss: 0.687997 Acc: 0.6717
# Elapsed 3786.16s, 35.38 s/epoch, 0.47 s/batch, ets 10367.71s
#
# Test set: Average loss: 0.6227, Accuracy: 431/600 (72%)
#
#
# Test set: Average loss: 0.6227, Accuracy: 431/600 (72%)
#
# Initial Test Loss : 0.622660,
# Initial Test Accuracy : 71.833%
#
# Epoch: 107
# Train Loss: 0.683499 Acc: 0.6646
# Elapsed 3820.11s, 35.37 s/epoch, 0.47 s/batch, ets 10328.44s
#
# Test set: Average loss: 0.5895, Accuracy: 433/600 (72%)
#
#
# Test set: Average loss: 0.5895, Accuracy: 433/600 (72%)
#
# Initial Test Loss : 0.589535,
# Initial Test Accuracy : 72.167%
#
# Epoch: 108
# Train Loss: 0.689432 Acc: 0.6542
# Elapsed 3854.12s, 35.36 s/epoch, 0.47 s/batch, ets 10289.45s
#
# Test set: Average loss: 0.5932, Accuracy: 419/600 (70%)
#
#
# Test set: Average loss: 0.5932, Accuracy: 419/600 (70%)
#
# Initial Test Loss : 0.593227,
# Initial Test Accuracy : 69.833%
#
# Epoch: 109
# Train Loss: 0.683538 Acc: 0.6758
# Elapsed 3888.22s, 35.35 s/epoch, 0.47 s/batch, ets 10250.76s
#
# Test set: Average loss: 0.6031, Accuracy: 432/600 (72%)
#
#
# Test set: Average loss: 0.6031, Accuracy: 432/600 (72%)
#
# Initial Test Loss : 0.603055,
# Initial Test Accuracy : 72.000%
#
# Epoch: 110
# Train Loss: 0.683718 Acc: 0.6679
# Elapsed 3922.25s, 35.34 s/epoch, 0.47 s/batch, ets 10211.98s
#
# Test set: Average loss: 0.6097, Accuracy: 433/600 (72%)
#
#
# Test set: Average loss: 0.6097, Accuracy: 433/600 (72%)
#
# Initial Test Loss : 0.609657,
# Initial Test Accuracy : 72.167%
#
# Epoch: 111
# Train Loss: 0.672372 Acc: 0.6700
# Elapsed 3956.26s, 35.32 s/epoch, 0.47 s/batch, ets 10173.23s
#
# Test set: Average loss: 0.5727, Accuracy: 441/600 (74%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5727, Accuracy: 441/600 (74%)
#
# Initial Test Loss : 0.572735,
# Initial Test Accuracy : 73.500%
#
# Epoch: 112
# Train Loss: 0.670777 Acc: 0.6658
# Elapsed 3998.04s, 35.38 s/epoch, 0.47 s/batch, ets 10154.32s
#
# Test set: Average loss: 0.6477, Accuracy: 429/600 (72%)
#
#
# Test set: Average loss: 0.6477, Accuracy: 429/600 (72%)
#
# Initial Test Loss : 0.647661,
# Initial Test Accuracy : 71.500%
#
# Epoch: 113
# Train Loss: 0.668552 Acc: 0.6787
# Elapsed 4032.06s, 35.37 s/epoch, 0.47 s/batch, ets 10115.52s
#
# Test set: Average loss: 0.5885, Accuracy: 430/600 (72%)
#
#
# Test set: Average loss: 0.5885, Accuracy: 430/600 (72%)
#
# Initial Test Loss : 0.588461,
# Initial Test Accuracy : 71.667%
#
# Epoch: 114
# Train Loss: 0.686306 Acc: 0.6696
# Elapsed 4066.04s, 35.36 s/epoch, 0.47 s/batch, ets 10076.72s
#
# Test set: Average loss: 0.5410, Accuracy: 450/600 (75%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5410, Accuracy: 450/600 (75%)
#
# Initial Test Loss : 0.541048,
# Initial Test Accuracy : 75.000%
#
# Epoch: 115
# Train Loss: 0.671894 Acc: 0.6850
# Elapsed 4107.94s, 35.41 s/epoch, 0.47 s/batch, ets 10057.37s
#
# Test set: Average loss: 0.6006, Accuracy: 429/600 (72%)
#
#
# Test set: Average loss: 0.6006, Accuracy: 429/600 (72%)
#
# Initial Test Loss : 0.600611,
# Initial Test Accuracy : 71.500%
#
# Epoch: 116
# Train Loss: 0.665313 Acc: 0.6787
# Elapsed 4142.02s, 35.40 s/epoch, 0.47 s/batch, ets 10018.72s
#
# Test set: Average loss: 0.5735, Accuracy: 438/600 (73%)
#
#
# Test set: Average loss: 0.5735, Accuracy: 438/600 (73%)
#
# Initial Test Loss : 0.573528,
# Initial Test Accuracy : 73.000%
#
# Epoch: 117
# Train Loss: 0.673050 Acc: 0.6646
# Elapsed 4176.02s, 35.39 s/epoch, 0.47 s/batch, ets 9979.99s
#
# Test set: Average loss: 0.5777, Accuracy: 438/600 (73%)
#
#
# Test set: Average loss: 0.5777, Accuracy: 438/600 (73%)
#
# Initial Test Loss : 0.577697,
# Initial Test Accuracy : 73.000%
#
# Epoch: 118
# Train Loss: 0.665854 Acc: 0.6792
# Elapsed 4210.01s, 35.38 s/epoch, 0.47 s/batch, ets 9941.28s
#
# Test set: Average loss: 0.5886, Accuracy: 427/600 (71%)
#
#
# Test set: Average loss: 0.5886, Accuracy: 427/600 (71%)
#
# Initial Test Loss : 0.588583,
# Initial Test Accuracy : 71.167%
#
# Epoch: 119
# Train Loss: 0.665170 Acc: 0.6700
# Elapsed 4243.96s, 35.37 s/epoch, 0.47 s/batch, ets 9902.58s
#
# Test set: Average loss: 0.6264, Accuracy: 422/600 (70%)
#
#
# Test set: Average loss: 0.6264, Accuracy: 422/600 (70%)
#
# Initial Test Loss : 0.626419,
# Initial Test Accuracy : 70.333%
#
# Epoch: 120
# Train Loss: 0.650638 Acc: 0.6725
# Elapsed 4278.05s, 35.36 s/epoch, 0.47 s/batch, ets 9864.27s
#
# Test set: Average loss: 0.5475, Accuracy: 440/600 (73%)
#
#
# Test set: Average loss: 0.5475, Accuracy: 440/600 (73%)
#
# Initial Test Loss : 0.547530,
# Initial Test Accuracy : 73.333%
#
# Epoch: 121
# Train Loss: 0.649530 Acc: 0.6850
# Elapsed 4312.03s, 35.34 s/epoch, 0.47 s/batch, ets 9825.76s
#
# Test set: Average loss: 0.5813, Accuracy: 441/600 (74%)
#
#
# Test set: Average loss: 0.5813, Accuracy: 441/600 (74%)
#
# Initial Test Loss : 0.581319,
# Initial Test Accuracy : 73.500%
#
# Epoch: 122
# Train Loss: 0.645300 Acc: 0.6871
# Elapsed 4345.92s, 35.33 s/epoch, 0.47 s/batch, ets 9787.16s
#
# Test set: Average loss: 0.5336, Accuracy: 455/600 (76%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5336, Accuracy: 455/600 (76%)
#
# Initial Test Loss : 0.533606,
# Initial Test Accuracy : 75.833%
#
# Epoch: 123
# Train Loss: 0.670085 Acc: 0.6796
# Elapsed 4387.64s, 35.38 s/epoch, 0.47 s/batch, ets 9766.03s
#
# Test set: Average loss: 0.5531, Accuracy: 456/600 (76%)
#
#
# Test set: Average loss: 0.5531, Accuracy: 456/600 (76%)
#
# Initial Test Loss : 0.553130,
# Initial Test Accuracy : 76.000%
#
# Epoch: 124
# Train Loss: 0.649051 Acc: 0.6733
# Elapsed 4421.89s, 35.38 s/epoch, 0.47 s/batch, ets 9728.16s
#
# Test set: Average loss: 0.5855, Accuracy: 449/600 (75%)
#
#
# Test set: Average loss: 0.5855, Accuracy: 449/600 (75%)
#
# Initial Test Loss : 0.585499,
# Initial Test Accuracy : 74.833%
#
# Epoch: 125
# Train Loss: 0.638874 Acc: 0.6921
# Elapsed 4455.91s, 35.36 s/epoch, 0.47 s/batch, ets 9689.83s
#
# Test set: Average loss: 0.5717, Accuracy: 442/600 (74%)
#
#
# Test set: Average loss: 0.5717, Accuracy: 442/600 (74%)
#
# Initial Test Loss : 0.571722,
# Initial Test Accuracy : 73.667%
#
# Epoch: 126
# Train Loss: 0.694619 Acc: 0.6704
# Elapsed 4489.88s, 35.35 s/epoch, 0.47 s/batch, ets 9651.48s
#
# Test set: Average loss: 0.6245, Accuracy: 421/600 (70%)
#
#
# Test set: Average loss: 0.6245, Accuracy: 421/600 (70%)
#
# Initial Test Loss : 0.624455,
# Initial Test Accuracy : 70.167%
#
# Epoch: 127
# Train Loss: 0.664435 Acc: 0.6842
# Elapsed 4523.83s, 35.34 s/epoch, 0.47 s/batch, ets 9613.14s
#
# Test set: Average loss: 0.5613, Accuracy: 454/600 (76%)
#
#
# Test set: Average loss: 0.5613, Accuracy: 454/600 (76%)
#
# Initial Test Loss : 0.561325,
# Initial Test Accuracy : 75.667%
#
# Epoch: 128
# Train Loss: 0.632336 Acc: 0.7054
# Elapsed 4557.79s, 35.33 s/epoch, 0.47 s/batch, ets 9574.90s
#
# Test set: Average loss: 0.6064, Accuracy: 451/600 (75%)
#
#
# Test set: Average loss: 0.6064, Accuracy: 451/600 (75%)
#
# Initial Test Loss : 0.606405,
# Initial Test Accuracy : 75.167%
#
# Epoch: 129
# Train Loss: 0.678033 Acc: 0.6721
# Elapsed 4591.85s, 35.32 s/epoch, 0.47 s/batch, ets 9536.92s
#
# Test set: Average loss: 0.6725, Accuracy: 421/600 (70%)
#
#
# Test set: Average loss: 0.6725, Accuracy: 421/600 (70%)
#
# Initial Test Loss : 0.672456,
# Initial Test Accuracy : 70.167%
#
# Epoch: 130
# Train Loss: 0.659725 Acc: 0.6858
# Elapsed 4625.81s, 35.31 s/epoch, 0.47 s/batch, ets 9498.80s
#
# Test set: Average loss: 0.5684, Accuracy: 443/600 (74%)
#
#
# Test set: Average loss: 0.5684, Accuracy: 443/600 (74%)
#
# Initial Test Loss : 0.568364,
# Initial Test Accuracy : 73.833%
#
# Epoch: 131
# Train Loss: 0.661352 Acc: 0.6833
# Elapsed 4659.77s, 35.30 s/epoch, 0.47 s/batch, ets 9460.74s
#
# Test set: Average loss: 0.5653, Accuracy: 443/600 (74%)
#
#
# Test set: Average loss: 0.5653, Accuracy: 443/600 (74%)
#
# Initial Test Loss : 0.565296,
# Initial Test Accuracy : 73.833%
#
# Epoch: 132
# Train Loss: 0.633564 Acc: 0.6958
# Elapsed 4693.77s, 35.29 s/epoch, 0.47 s/batch, ets 9422.84s
#
# Test set: Average loss: 0.5709, Accuracy: 445/600 (74%)
#
#
# Test set: Average loss: 0.5709, Accuracy: 445/600 (74%)
#
# Initial Test Loss : 0.570861,
# Initial Test Accuracy : 74.167%
#
# Epoch: 133
# Train Loss: 0.658310 Acc: 0.6846
# Elapsed 4727.72s, 35.28 s/epoch, 0.47 s/batch, ets 9384.87s
#
# Test set: Average loss: 0.5480, Accuracy: 450/600 (75%)
#
#
# Test set: Average loss: 0.5480, Accuracy: 450/600 (75%)
#
# Initial Test Loss : 0.548019,
# Initial Test Accuracy : 75.000%
#
# Epoch: 134
# Train Loss: 0.628026 Acc: 0.7142
# Elapsed 4761.65s, 35.27 s/epoch, 0.47 s/batch, ets 9346.95s
#
# Test set: Average loss: 0.5462, Accuracy: 453/600 (76%)
#
#
# Test set: Average loss: 0.5462, Accuracy: 453/600 (76%)
#
# Initial Test Loss : 0.546231,
# Initial Test Accuracy : 75.500%
#
# Epoch: 135
# Train Loss: 0.643071 Acc: 0.6846
# Elapsed 4795.65s, 35.26 s/epoch, 0.47 s/batch, ets 9309.20s
#
# Test set: Average loss: 0.5881, Accuracy: 443/600 (74%)
#
#
# Test set: Average loss: 0.5881, Accuracy: 443/600 (74%)
#
# Initial Test Loss : 0.588071,
# Initial Test Accuracy : 73.833%
#
# Epoch: 136
# Train Loss: 0.663475 Acc: 0.6717
# Elapsed 4829.66s, 35.25 s/epoch, 0.47 s/batch, ets 9271.53s
#
# Test set: Average loss: 0.5919, Accuracy: 447/600 (74%)
#
#
# Test set: Average loss: 0.5919, Accuracy: 447/600 (74%)
#
# Initial Test Loss : 0.591913,
# Initial Test Accuracy : 74.500%
#
# Epoch: 137
# Train Loss: 0.626325 Acc: 0.7021
# Elapsed 4863.69s, 35.24 s/epoch, 0.47 s/batch, ets 9233.97s
#
# Test set: Average loss: 0.5146, Accuracy: 459/600 (76%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5146, Accuracy: 459/600 (76%)
#
# Initial Test Loss : 0.514577,
# Initial Test Accuracy : 76.500%
#
# Epoch: 138
# Train Loss: 0.625587 Acc: 0.7067
# Elapsed 4905.02s, 35.29 s/epoch, 0.47 s/batch, ets 9210.14s
#
# Test set: Average loss: 0.6062, Accuracy: 446/600 (74%)
#
#
# Test set: Average loss: 0.6062, Accuracy: 446/600 (74%)
#
# Initial Test Loss : 0.606153,
# Initial Test Accuracy : 74.333%
#
# Epoch: 139
# Train Loss: 0.644487 Acc: 0.6863
# Elapsed 4938.98s, 35.28 s/epoch, 0.47 s/batch, ets 9172.39s
#
# Test set: Average loss: 0.5469, Accuracy: 449/600 (75%)
#
#
# Test set: Average loss: 0.5469, Accuracy: 449/600 (75%)
#
# Initial Test Loss : 0.546949,
# Initial Test Accuracy : 74.833%
#
# Epoch: 140
# Train Loss: 0.625850 Acc: 0.7033
# Elapsed 4973.01s, 35.27 s/epoch, 0.47 s/batch, ets 9134.82s
#
# Test set: Average loss: 0.5202, Accuracy: 450/600 (75%)
#
#
# Test set: Average loss: 0.5202, Accuracy: 450/600 (75%)
#
# Initial Test Loss : 0.520201,
# Initial Test Accuracy : 75.000%
#
# Epoch: 141
# Train Loss: 0.633622 Acc: 0.6979
# Elapsed 5007.15s, 35.26 s/epoch, 0.47 s/batch, ets 9097.50s
#
# Test set: Average loss: 0.5207, Accuracy: 456/600 (76%)
#
#
# Test set: Average loss: 0.5207, Accuracy: 456/600 (76%)
#
# Initial Test Loss : 0.520720,
# Initial Test Accuracy : 76.000%
#
# Epoch: 142
# Train Loss: 0.645295 Acc: 0.6937
# Elapsed 5041.18s, 35.25 s/epoch, 0.47 s/batch, ets 9060.02s
#
# Test set: Average loss: 0.5876, Accuracy: 444/600 (74%)
#
#
# Test set: Average loss: 0.5876, Accuracy: 444/600 (74%)
#
# Initial Test Loss : 0.587593,
# Initial Test Accuracy : 74.000%
#
# Epoch: 143
# Train Loss: 0.633572 Acc: 0.6979
# Elapsed 5075.07s, 35.24 s/epoch, 0.47 s/batch, ets 9022.35s
#
# Test set: Average loss: 0.6178, Accuracy: 431/600 (72%)
#
#
# Test set: Average loss: 0.6178, Accuracy: 431/600 (72%)
#
# Initial Test Loss : 0.617835,
# Initial Test Accuracy : 71.833%
#
# Epoch: 144
# Train Loss: 0.648319 Acc: 0.6833
# Elapsed 5108.99s, 35.23 s/epoch, 0.47 s/batch, ets 8984.78s
#
# Test set: Average loss: 0.6987, Accuracy: 418/600 (70%)
#
#
# Test set: Average loss: 0.6987, Accuracy: 418/600 (70%)
#
# Initial Test Loss : 0.698709,
# Initial Test Accuracy : 69.667%
#
# Epoch: 145
# Train Loss: 0.641367 Acc: 0.6975
# Elapsed 5143.02s, 35.23 s/epoch, 0.47 s/batch, ets 8947.44s
#
# Test set: Average loss: 0.5238, Accuracy: 457/600 (76%)
#
#
# Test set: Average loss: 0.5238, Accuracy: 457/600 (76%)
#
# Initial Test Loss : 0.523769,
# Initial Test Accuracy : 76.167%
#
# Epoch: 146
# Train Loss: 0.640408 Acc: 0.6967
# Elapsed 5177.13s, 35.22 s/epoch, 0.47 s/batch, ets 8910.30s
#
# Test set: Average loss: 0.5323, Accuracy: 459/600 (76%)
#
#
# Test set: Average loss: 0.5323, Accuracy: 459/600 (76%)
#
# Initial Test Loss : 0.532322,
# Initial Test Accuracy : 76.500%
#
# Epoch: 147
# Train Loss: 0.629114 Acc: 0.6892
# Elapsed 5211.10s, 35.21 s/epoch, 0.47 s/batch, ets 8872.95s
#
# Test set: Average loss: 0.5114, Accuracy: 440/600 (73%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.5114, Accuracy: 440/600 (73%)
#
# Initial Test Loss : 0.511401,
# Initial Test Accuracy : 73.333%
#
# Epoch: 148
# Train Loss: 0.625532 Acc: 0.7100
# Elapsed 5252.88s, 35.25 s/epoch, 0.47 s/batch, ets 8848.82s
#
# Test set: Average loss: 0.5634, Accuracy: 449/600 (75%)
#
#
# Test set: Average loss: 0.5634, Accuracy: 449/600 (75%)
#
# Initial Test Loss : 0.563422,
# Initial Test Accuracy : 74.833%
#
# Epoch: 149
# Train Loss: 0.667300 Acc: 0.6721
# Elapsed 5286.94s, 35.25 s/epoch, 0.47 s/batch, ets 8811.57s
#
# Test set: Average loss: 0.5376, Accuracy: 455/600 (76%)
#
#
# Test set: Average loss: 0.5376, Accuracy: 455/600 (76%)
#
# Initial Test Loss : 0.537600,
# Initial Test Accuracy : 75.833%
#
# Epoch: 150
# Train Loss: 0.619875 Acc: 0.6958
# Elapsed 5320.87s, 35.24 s/epoch, 0.47 s/batch, ets 8774.15s
#
# Test set: Average loss: 0.5146, Accuracy: 460/600 (77%)
#
#
# Test set: Average loss: 0.5146, Accuracy: 460/600 (77%)
#
# Initial Test Loss : 0.514572,
# Initial Test Accuracy : 76.667%
#
# Epoch: 151
# Train Loss: 0.639022 Acc: 0.6983
# Elapsed 5354.92s, 35.23 s/epoch, 0.47 s/batch, ets 8736.98s
#
# Test set: Average loss: 0.4995, Accuracy: 469/600 (78%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.4995, Accuracy: 469/600 (78%)
#
# Initial Test Loss : 0.499488,
# Initial Test Accuracy : 78.167%
#
# Epoch: 152
# Train Loss: 0.603408 Acc: 0.7121
# Elapsed 5396.58s, 35.27 s/epoch, 0.47 s/batch, ets 8712.13s
#
# Test set: Average loss: 0.5074, Accuracy: 462/600 (77%)
#
#
# Test set: Average loss: 0.5074, Accuracy: 462/600 (77%)
#
# Initial Test Loss : 0.507388,
# Initial Test Accuracy : 77.000%
#
# Epoch: 153
# Train Loss: 0.605303 Acc: 0.7092
# Elapsed 5430.49s, 35.26 s/epoch, 0.47 s/batch, ets 8674.68s
#
# Test set: Average loss: 0.5059, Accuracy: 464/600 (77%)
#
#
# Test set: Average loss: 0.5059, Accuracy: 464/600 (77%)
#
# Initial Test Loss : 0.505901,
# Initial Test Accuracy : 77.333%
#
# Epoch: 154
# Train Loss: 0.632983 Acc: 0.7058
# Elapsed 5464.32s, 35.25 s/epoch, 0.47 s/batch, ets 8637.16s
#
# Test set: Average loss: 0.5551, Accuracy: 441/600 (74%)
#
#
# Test set: Average loss: 0.5551, Accuracy: 441/600 (74%)
#
# Initial Test Loss : 0.555074,
# Initial Test Accuracy : 73.500%
#
# Epoch: 155
# Train Loss: 0.631085 Acc: 0.6875
# Elapsed 5498.28s, 35.25 s/epoch, 0.47 s/batch, ets 8599.87s
#
# Test set: Average loss: 0.5242, Accuracy: 465/600 (78%)
#
#
# Test set: Average loss: 0.5242, Accuracy: 465/600 (78%)
#
# Initial Test Loss : 0.524161,
# Initial Test Accuracy : 77.500%
#
# Epoch: 156
# Train Loss: 0.608266 Acc: 0.6996
# Elapsed 5532.35s, 35.24 s/epoch, 0.47 s/batch, ets 8562.80s
#
# Test set: Average loss: 0.5046, Accuracy: 465/600 (78%)
#
#
# Test set: Average loss: 0.5046, Accuracy: 465/600 (78%)
#
# Initial Test Loss : 0.504637,
# Initial Test Accuracy : 77.500%
#
# Epoch: 157
# Train Loss: 0.616430 Acc: 0.7029
# Elapsed 5566.34s, 35.23 s/epoch, 0.47 s/batch, ets 8525.66s
#
# Test set: Average loss: 0.5221, Accuracy: 458/600 (76%)
#
#
# Test set: Average loss: 0.5221, Accuracy: 458/600 (76%)
#
# Initial Test Loss : 0.522067,
# Initial Test Accuracy : 76.333%
#
# Epoch: 158
# Train Loss: 0.616349 Acc: 0.6992
# Elapsed 5600.27s, 35.22 s/epoch, 0.47 s/batch, ets 8488.47s
#
# Test set: Average loss: 0.5336, Accuracy: 455/600 (76%)
#
#
# Test set: Average loss: 0.5336, Accuracy: 455/600 (76%)
#
# Initial Test Loss : 0.533605,
# Initial Test Accuracy : 75.833%
#
# Epoch: 159
# Train Loss: 0.623196 Acc: 0.7029
# Elapsed 5634.23s, 35.21 s/epoch, 0.47 s/batch, ets 8451.35s
#
# Test set: Average loss: 0.5713, Accuracy: 454/600 (76%)
#
#
# Test set: Average loss: 0.5713, Accuracy: 454/600 (76%)
#
# Initial Test Loss : 0.571347,
# Initial Test Accuracy : 75.667%
#
# Epoch: 160
# Train Loss: 0.605760 Acc: 0.7046
# Elapsed 5668.07s, 35.21 s/epoch, 0.47 s/batch, ets 8414.10s
#
# Test set: Average loss: 0.5703, Accuracy: 452/600 (75%)
#
#
# Test set: Average loss: 0.5703, Accuracy: 452/600 (75%)
#
# Initial Test Loss : 0.570255,
# Initial Test Accuracy : 75.333%
#
# Epoch: 161
# Train Loss: 0.609602 Acc: 0.7200
# Elapsed 5701.96s, 35.20 s/epoch, 0.47 s/batch, ets 8376.96s
#
# Test set: Average loss: 0.5026, Accuracy: 462/600 (77%)
#
#
# Test set: Average loss: 0.5026, Accuracy: 462/600 (77%)
#
# Initial Test Loss : 0.502635,
# Initial Test Accuracy : 77.000%
#
# Epoch: 162
# Train Loss: 0.620971 Acc: 0.7067
# Elapsed 5735.93s, 35.19 s/epoch, 0.47 s/batch, ets 8339.97s
#
# Test set: Average loss: 0.5084, Accuracy: 458/600 (76%)
#
#
# Test set: Average loss: 0.5084, Accuracy: 458/600 (76%)
#
# Initial Test Loss : 0.508414,
# Initial Test Accuracy : 76.333%
#
# Epoch: 163
# Train Loss: 0.596785 Acc: 0.7250
# Elapsed 5769.95s, 35.18 s/epoch, 0.47 s/batch, ets 8303.10s
#
# Test set: Average loss: 0.5231, Accuracy: 456/600 (76%)
#
#
# Test set: Average loss: 0.5231, Accuracy: 456/600 (76%)
#
# Initial Test Loss : 0.523130,
# Initial Test Accuracy : 76.000%
#
# Epoch: 164
# Train Loss: 0.618122 Acc: 0.7142
# ...
#
# Test set: Average loss: 0.3543, Accuracy: 517/600 (86%)
#
#
# Test set: Average loss: 0.3543, Accuracy: 517/600 (86%)
#
# Initial Test Loss : 0.354309,
# Initial Test Accuracy : 86.167%
#
# Epoch: 345
# Train Loss: 0.483906 Acc: 0.7942
# Elapsed 12061.61s, 34.86 s/epoch, 0.46 s/batch, ets 1882.45s
#
# Test set: Average loss: 0.3462, Accuracy: 525/600 (88%)
#
#
# Test set: Average loss: 0.3462, Accuracy: 525/600 (88%)
#
# Initial Test Loss : 0.346247,
# Initial Test Accuracy : 87.500%
#
# Epoch: 346
# Train Loss: 0.467564 Acc: 0.7879
# Elapsed 12095.36s, 34.86 s/epoch, 0.46 s/batch, ets 1847.42s
#
# Test set: Average loss: 0.4040, Accuracy: 504/600 (84%)
#
#
# Test set: Average loss: 0.4040, Accuracy: 504/600 (84%)
#
# Initial Test Loss : 0.404039,
# Initial Test Accuracy : 84.000%
#
# Epoch: 347
# Train Loss: 0.447889 Acc: 0.7942
# Elapsed 12129.24s, 34.85 s/epoch, 0.46 s/batch, ets 1812.42s
#
# Test set: Average loss: 0.3611, Accuracy: 512/600 (85%)
#
#
# Test set: Average loss: 0.3611, Accuracy: 512/600 (85%)
#
# Initial Test Loss : 0.361083,
# Initial Test Accuracy : 85.333%
#
# Epoch: 348
# Train Loss: 0.460913 Acc: 0.7913
# Elapsed 12163.08s, 34.85 s/epoch, 0.46 s/batch, ets 1777.41s
#
# Test set: Average loss: 0.3859, Accuracy: 500/600 (83%)
#
#
# Test set: Average loss: 0.3859, Accuracy: 500/600 (83%)
#
# Initial Test Loss : 0.385855,
# Initial Test Accuracy : 83.333%
#
# Epoch: 349
# Train Loss: 0.476922 Acc: 0.7850
# Elapsed 12196.88s, 34.85 s/epoch, 0.46 s/batch, ets 1742.41s
#
# Test set: Average loss: 0.4101, Accuracy: 497/600 (83%)
#
#
# Test set: Average loss: 0.4101, Accuracy: 497/600 (83%)
#
# Initial Test Loss : 0.410139,
# Initial Test Accuracy : 82.833%
#
# Epoch: 350
# Train Loss: 0.491064 Acc: 0.7808
# Elapsed 12230.86s, 34.85 s/epoch, 0.46 s/batch, ets 1707.44s
#
# Test set: Average loss: 0.3682, Accuracy: 507/600 (84%)
#
#
# Test set: Average loss: 0.3682, Accuracy: 507/600 (84%)
#
# Initial Test Loss : 0.368234,
# Initial Test Accuracy : 84.500%
#
# Epoch: 351
# Train Loss: 0.472034 Acc: 0.7933
# Elapsed 12264.65s, 34.84 s/epoch, 0.46 s/batch, ets 1672.45s
#
# Test set: Average loss: 0.3458, Accuracy: 516/600 (86%)
#
#
# Test set: Average loss: 0.3458, Accuracy: 516/600 (86%)
#
# Initial Test Loss : 0.345824,
# Initial Test Accuracy : 86.000%
#
# Epoch: 352
# Train Loss: 0.494638 Acc: 0.7783
# Elapsed 12298.52s, 34.84 s/epoch, 0.46 s/batch, ets 1637.48s
#
# Test set: Average loss: 0.3552, Accuracy: 514/600 (86%)
#
#
# Test set: Average loss: 0.3552, Accuracy: 514/600 (86%)
#
# Initial Test Loss : 0.355170,
# Initial Test Accuracy : 85.667%
#
# Epoch: 353
# Train Loss: 0.472632 Acc: 0.7925
# Elapsed 12332.36s, 34.84 s/epoch, 0.46 s/batch, ets 1602.51s
#
# Test set: Average loss: 0.3395, Accuracy: 514/600 (86%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.3395, Accuracy: 514/600 (86%)
#
# Initial Test Loss : 0.339543,
# Initial Test Accuracy : 85.667%
#
# Epoch: 354
# Train Loss: 0.488606 Acc: 0.7788
# Elapsed 12374.05s, 34.86 s/epoch, 0.46 s/batch, ets 1568.54s
#
# Test set: Average loss: 0.3650, Accuracy: 510/600 (85%)
#
#
# Test set: Average loss: 0.3650, Accuracy: 510/600 (85%)
#
# Initial Test Loss : 0.364979,
# Initial Test Accuracy : 85.000%
#
# Epoch: 355
# Train Loss: 0.494243 Acc: 0.7746
# Elapsed 12407.88s, 34.85 s/epoch, 0.46 s/batch, ets 1533.56s
#
# Test set: Average loss: 0.3399, Accuracy: 511/600 (85%)
#
#
# Test set: Average loss: 0.3399, Accuracy: 511/600 (85%)
#
# Initial Test Loss : 0.339884,
# Initial Test Accuracy : 85.167%
#
# Epoch: 356
# Train Loss: 0.472912 Acc: 0.7833
# Elapsed 12441.71s, 34.85 s/epoch, 0.46 s/batch, ets 1498.58s
#
# Test set: Average loss: 0.3870, Accuracy: 503/600 (84%)
#
#
# Test set: Average loss: 0.3870, Accuracy: 503/600 (84%)
#
# Initial Test Loss : 0.386979,
# Initial Test Accuracy : 83.833%
#
# Epoch: 357
# Train Loss: 0.480268 Acc: 0.7925
# Elapsed 12475.51s, 34.85 s/epoch, 0.46 s/batch, ets 1463.61s
#
# Test set: Average loss: 0.3542, Accuracy: 514/600 (86%)
#
#
# Test set: Average loss: 0.3542, Accuracy: 514/600 (86%)
#
# Initial Test Loss : 0.354232,
# Initial Test Accuracy : 85.667%
#
# Epoch: 358
# Train Loss: 0.487903 Acc: 0.7829
# Elapsed 12509.28s, 34.84 s/epoch, 0.46 s/batch, ets 1428.64s
#
# Test set: Average loss: 0.3750, Accuracy: 503/600 (84%)
#
#
# Test set: Average loss: 0.3750, Accuracy: 503/600 (84%)
#
# Initial Test Loss : 0.375035,
# Initial Test Accuracy : 83.833%
#
# Epoch: 359
# Train Loss: 0.451412 Acc: 0.7925
# Elapsed 12543.17s, 34.84 s/epoch, 0.46 s/batch, ets 1393.69s
#
# Test set: Average loss: 0.4015, Accuracy: 514/600 (86%)
#
#
# Test set: Average loss: 0.4015, Accuracy: 514/600 (86%)
#
# Initial Test Loss : 0.401508,
# Initial Test Accuracy : 85.667%
#
# Epoch: 360
# Train Loss: 0.441475 Acc: 0.8179
# Elapsed 12577.00s, 34.84 s/epoch, 0.46 s/batch, ets 1358.73s
#
# Test set: Average loss: 0.3340, Accuracy: 531/600 (88%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.3340, Accuracy: 531/600 (88%)
#
# Initial Test Loss : 0.334012,
# Initial Test Accuracy : 88.500%
#
# Epoch: 361
# Train Loss: 0.506571 Acc: 0.7679
# Elapsed 12618.78s, 34.86 s/epoch, 0.46 s/batch, ets 1324.62s
#
# Test set: Average loss: 0.3962, Accuracy: 499/600 (83%)
#
#
# Test set: Average loss: 0.3962, Accuracy: 499/600 (83%)
#
# Initial Test Loss : 0.396181,
# Initial Test Accuracy : 83.167%
#
# Epoch: 362
# Train Loss: 0.452265 Acc: 0.8100
# Elapsed 12652.62s, 34.86 s/epoch, 0.46 s/batch, ets 1289.66s
#
# Test set: Average loss: 0.4760, Accuracy: 485/600 (81%)
#
#
# Test set: Average loss: 0.4760, Accuracy: 485/600 (81%)
#
# Initial Test Loss : 0.476031,
# Initial Test Accuracy : 80.833%
#
# Epoch: 363
# Train Loss: 0.477834 Acc: 0.7921
# Elapsed 12686.49s, 34.85 s/epoch, 0.46 s/batch, ets 1254.71s
#
# Test set: Average loss: 0.3525, Accuracy: 513/600 (86%)
#
#
# Test set: Average loss: 0.3525, Accuracy: 513/600 (86%)
#
# Initial Test Loss : 0.352491,
# Initial Test Accuracy : 85.500%
#
# Epoch: 364
# Train Loss: 0.457605 Acc: 0.7958
# Elapsed 12720.36s, 34.85 s/epoch, 0.46 s/batch, ets 1219.76s
#
# Test set: Average loss: 0.3496, Accuracy: 517/600 (86%)
#
#
# Test set: Average loss: 0.3496, Accuracy: 517/600 (86%)
#
# Initial Test Loss : 0.349640,
# Initial Test Accuracy : 86.167%
#
# Epoch: 365
# Train Loss: 0.492079 Acc: 0.7808
# Elapsed 12754.15s, 34.85 s/epoch, 0.46 s/batch, ets 1184.81s
#
# Test set: Average loss: 0.3428, Accuracy: 506/600 (84%)
#
#
# Test set: Average loss: 0.3428, Accuracy: 506/600 (84%)
#
# Initial Test Loss : 0.342841,
# Initial Test Accuracy : 84.333%
#
# Epoch: 366
# Train Loss: 0.441140 Acc: 0.8042
# Elapsed 12788.05s, 34.84 s/epoch, 0.46 s/batch, ets 1149.88s
#
# Test set: Average loss: 0.3467, Accuracy: 513/600 (86%)
#
#
# Test set: Average loss: 0.3467, Accuracy: 513/600 (86%)
#
# Initial Test Loss : 0.346672,
# Initial Test Accuracy : 85.500%
#
# Epoch: 367
# Train Loss: 0.469575 Acc: 0.8017
# Elapsed 12821.91s, 34.84 s/epoch, 0.46 s/batch, ets 1114.95s
#
# Test set: Average loss: 0.3874, Accuracy: 493/600 (82%)
#
#
# Test set: Average loss: 0.3874, Accuracy: 493/600 (82%)
#
# Initial Test Loss : 0.387380,
# Initial Test Accuracy : 82.167%
#
# Epoch: 368
# Train Loss: 0.452034 Acc: 0.7983
# Elapsed 12855.83s, 34.84 s/epoch, 0.46 s/batch, ets 1080.03s
#
# Test set: Average loss: 0.3960, Accuracy: 497/600 (83%)
#
#
# Test set: Average loss: 0.3960, Accuracy: 497/600 (83%)
#
# Initial Test Loss : 0.395983,
# Initial Test Accuracy : 82.833%
#
# Epoch: 369
# Train Loss: 0.454946 Acc: 0.8021
# Elapsed 12889.64s, 34.84 s/epoch, 0.46 s/batch, ets 1045.11s
#
# Test set: Average loss: 0.3697, Accuracy: 507/600 (84%)
#
#
# Test set: Average loss: 0.3697, Accuracy: 507/600 (84%)
#
# Initial Test Loss : 0.369693,
# Initial Test Accuracy : 84.500%
#
# Epoch: 370
# Train Loss: 0.474746 Acc: 0.7954
# Elapsed 12923.62s, 34.83 s/epoch, 0.46 s/batch, ets 1010.20s
#
# Test set: Average loss: 0.3854, Accuracy: 505/600 (84%)
#
#
# Test set: Average loss: 0.3854, Accuracy: 505/600 (84%)
#
# Initial Test Loss : 0.385444,
# Initial Test Accuracy : 84.167%
#
# Epoch: 371
# Train Loss: 0.454890 Acc: 0.7987
# Elapsed 12957.50s, 34.83 s/epoch, 0.46 s/batch, ets 975.30s
#
# Test set: Average loss: 0.4051, Accuracy: 511/600 (85%)
#
#
# Test set: Average loss: 0.4051, Accuracy: 511/600 (85%)
#
# Initial Test Loss : 0.405059,
# Initial Test Accuracy : 85.167%
#
# Epoch: 372
# Train Loss: 0.459990 Acc: 0.7967
# Elapsed 12991.50s, 34.83 s/epoch, 0.46 s/batch, ets 940.40s
#
# Test set: Average loss: 0.3477, Accuracy: 522/600 (87%)
#
#
# Test set: Average loss: 0.3477, Accuracy: 522/600 (87%)
#
# Initial Test Loss : 0.347711,
# Initial Test Accuracy : 87.000%
#
# Epoch: 373
# Train Loss: 0.472283 Acc: 0.7812
# Elapsed 13025.33s, 34.83 s/epoch, 0.46 s/batch, ets 905.50s
#
# Test set: Average loss: 0.3350, Accuracy: 514/600 (86%)
#
#
# Test set: Average loss: 0.3350, Accuracy: 514/600 (86%)
#
# Initial Test Loss : 0.335014,
# Initial Test Accuracy : 85.667%
#
# Epoch: 374
# Train Loss: 0.511108 Acc: 0.7779
# Elapsed 13059.21s, 34.82 s/epoch, 0.46 s/batch, ets 870.61s
#
# Test set: Average loss: 0.3506, Accuracy: 525/600 (88%)
#
#
# Test set: Average loss: 0.3506, Accuracy: 525/600 (88%)
#
# Initial Test Loss : 0.350563,
# Initial Test Accuracy : 87.500%
#
# Epoch: 375
# Train Loss: 0.473705 Acc: 0.7925
# Elapsed 13093.04s, 34.82 s/epoch, 0.46 s/batch, ets 835.73s
#
# Test set: Average loss: 0.3441, Accuracy: 512/600 (85%)
#
#
# Test set: Average loss: 0.3441, Accuracy: 512/600 (85%)
#
# Initial Test Loss : 0.344052,
# Initial Test Accuracy : 85.333%
#
# Epoch: 376
# Train Loss: 0.456994 Acc: 0.7967
# Elapsed 13126.81s, 34.82 s/epoch, 0.46 s/batch, ets 800.84s
#
# Test set: Average loss: 0.3436, Accuracy: 521/600 (87%)
#
#
# Test set: Average loss: 0.3436, Accuracy: 521/600 (87%)
#
# Initial Test Loss : 0.343576,
# Initial Test Accuracy : 86.833%
#
# Epoch: 377
# Train Loss: 0.459858 Acc: 0.7987
# Elapsed 13160.65s, 34.82 s/epoch, 0.46 s/batch, ets 765.96s
#
# Test set: Average loss: 0.3324, Accuracy: 520/600 (87%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.3324, Accuracy: 520/600 (87%)
#
# Initial Test Loss : 0.332372,
# Initial Test Accuracy : 86.667%
#
# Epoch: 378
# Train Loss: 0.432047 Acc: 0.8067
# Elapsed 13202.47s, 34.84 s/epoch, 0.46 s/batch, ets 731.54s
#
# Test set: Average loss: 0.3638, Accuracy: 517/600 (86%)
#
#
# Test set: Average loss: 0.3638, Accuracy: 517/600 (86%)
#
# Initial Test Loss : 0.363766,
# Initial Test Accuracy : 86.167%
#
# Epoch: 379
# Train Loss: 0.465586 Acc: 0.7921
# Elapsed 13236.29s, 34.83 s/epoch, 0.46 s/batch, ets 696.65s
#
# Test set: Average loss: 0.3368, Accuracy: 516/600 (86%)
#
#
# Test set: Average loss: 0.3368, Accuracy: 516/600 (86%)
#
# Initial Test Loss : 0.336794,
# Initial Test Accuracy : 86.000%
#
# Epoch: 380
# Train Loss: 0.459391 Acc: 0.8017
# Elapsed 13270.10s, 34.83 s/epoch, 0.46 s/batch, ets 661.76s
#
# Test set: Average loss: 0.3613, Accuracy: 510/600 (85%)
#
#
# Test set: Average loss: 0.3613, Accuracy: 510/600 (85%)
#
# Initial Test Loss : 0.361298,
# Initial Test Accuracy : 85.000%
#
# Epoch: 381
# Train Loss: 0.480814 Acc: 0.7825
# Elapsed 13303.92s, 34.83 s/epoch, 0.46 s/batch, ets 626.89s
#
# Test set: Average loss: 0.4018, Accuracy: 503/600 (84%)
#
#
# Test set: Average loss: 0.4018, Accuracy: 503/600 (84%)
#
# Initial Test Loss : 0.401751,
# Initial Test Accuracy : 83.833%
#
# Epoch: 382
# Train Loss: 0.478122 Acc: 0.7837
# Elapsed 13337.74s, 34.82 s/epoch, 0.46 s/batch, ets 592.01s
#
# Test set: Average loss: 0.3360, Accuracy: 516/600 (86%)
#
#
# Test set: Average loss: 0.3360, Accuracy: 516/600 (86%)
#
# Initial Test Loss : 0.336003,
# Initial Test Accuracy : 86.000%
#
# Epoch: 383
# Train Loss: 0.459818 Acc: 0.7917
# Elapsed 13371.66s, 34.82 s/epoch, 0.46 s/batch, ets 557.15s
#
# Test set: Average loss: 0.3133, Accuracy: 529/600 (88%)
#
# Model Improved. Saving the Model...
#
#
# Test set: Average loss: 0.3133, Accuracy: 529/600 (88%)
#
# Initial Test Loss : 0.313330,
# Initial Test Accuracy : 88.167%
#
# Epoch: 384
# Train Loss: 0.443442 Acc: 0.8042
# Elapsed 13413.93s, 34.84 s/epoch, 0.46 s/batch, ets 522.62s
#
# Test set: Average loss: 0.3642, Accuracy: 513/600 (86%)
#
#
# Test set: Average loss: 0.3642, Accuracy: 513/600 (86%)
#
# Initial Test Loss : 0.364244,
# Initial Test Accuracy : 85.500%
#
# Epoch: 385
# Train Loss: 0.463919 Acc: 0.7883
# Elapsed 13447.86s, 34.84 s/epoch, 0.46 s/batch, ets 487.75s
#
# Test set: Average loss: 0.3585, Accuracy: 505/600 (84%)
#
#
# Test set: Average loss: 0.3585, Accuracy: 505/600 (84%)
#
# Initial Test Loss : 0.358469,
# Initial Test Accuracy : 84.167%
#
# Epoch: 386
# Train Loss: 0.451969 Acc: 0.8037
# Elapsed 13481.68s, 34.84 s/epoch, 0.46 s/batch, ets 452.87s
#
# Test set: Average loss: 0.3278, Accuracy: 518/600 (86%)
#
#
# Test set: Average loss: 0.3278, Accuracy: 518/600 (86%)
#
# Initial Test Loss : 0.327820,
# Initial Test Accuracy : 86.333%
#
# Epoch: 387
# Train Loss: 0.451365 Acc: 0.7954
# Elapsed 13515.60s, 34.83 s/epoch, 0.46 s/batch, ets 418.01s
#
# Test set: Average loss: 0.3265, Accuracy: 520/600 (87%)
#
#
# Test set: Average loss: 0.3265, Accuracy: 520/600 (87%)
#
# Initial Test Loss : 0.326512,
# Initial Test Accuracy : 86.667%
#
# Epoch: 388
# Train Loss: 0.439011 Acc: 0.8025
# Elapsed 13549.49s, 34.83 s/epoch, 0.46 s/batch, ets 383.15s
#
# Test set: Average loss: 0.3505, Accuracy: 511/600 (85%)
#
#
# Test set: Average loss: 0.3505, Accuracy: 511/600 (85%)
#
# Initial Test Loss : 0.350483,
# Initial Test Accuracy : 85.167%
#
# Epoch: 389
# Train Loss: 0.454625 Acc: 0.8021
# Elapsed 13583.34s, 34.83 s/epoch, 0.46 s/batch, ets 348.29s
#
# Test set: Average loss: 0.3835, Accuracy: 505/600 (84%)
#
#
# Test set: Average loss: 0.3835, Accuracy: 505/600 (84%)
#
# Initial Test Loss : 0.383508,
# Initial Test Accuracy : 84.167%
#
# Epoch: 390
# Train Loss: 0.466027 Acc: 0.7908
# Elapsed 13617.14s, 34.83 s/epoch, 0.46 s/batch, ets 313.44s
#
# Test set: Average loss: 0.3385, Accuracy: 527/600 (88%)
#
#
# Test set: Average loss: 0.3385, Accuracy: 527/600 (88%)
#
# Initial Test Loss : 0.338484,
# Initial Test Accuracy : 87.833%
#
# Epoch: 391
# Train Loss: 0.456677 Acc: 0.8008
# Elapsed 13651.08s, 34.82 s/epoch, 0.46 s/batch, ets 278.59s
#
# Test set: Average loss: 0.3669, Accuracy: 516/600 (86%)
#
#
# Test set: Average loss: 0.3669, Accuracy: 516/600 (86%)
#
# Initial Test Loss : 0.366938,
# Initial Test Accuracy : 86.000%
#
# Epoch: 392
# Train Loss: 0.465946 Acc: 0.7883
# Elapsed 13684.82s, 34.82 s/epoch, 0.46 s/batch, ets 243.75s
#
# Test set: Average loss: 0.3141, Accuracy: 533/600 (89%)
#
#
# Test set: Average loss: 0.3141, Accuracy: 533/600 (89%)
#
# Initial Test Loss : 0.314064,
# Initial Test Accuracy : 88.833%
#
# Epoch: 393
# Train Loss: 0.482734 Acc: 0.7929
# Elapsed 13718.60s, 34.82 s/epoch, 0.46 s/batch, ets 208.91s
#
# Test set: Average loss: 0.3596, Accuracy: 506/600 (84%)
#
#
# Test set: Average loss: 0.3596, Accuracy: 506/600 (84%)
#
# Initial Test Loss : 0.359584,
# Initial Test Accuracy : 84.333%
#
# Epoch: 394
# Train Loss: 0.437561 Acc: 0.8092
# Elapsed 13752.42s, 34.82 s/epoch, 0.46 s/batch, ets 174.08s
#
# Test set: Average loss: 0.3329, Accuracy: 518/600 (86%)
#
#
# Test set: Average loss: 0.3329, Accuracy: 518/600 (86%)
#
# Initial Test Loss : 0.332909,
# Initial Test Accuracy : 86.333%
#
# Epoch: 395
# Train Loss: 0.464075 Acc: 0.7875
# Elapsed 13786.37s, 34.81 s/epoch, 0.46 s/batch, ets 139.26s
#
# Test set: Average loss: 0.3400, Accuracy: 519/600 (86%)
#
#
# Test set: Average loss: 0.3400, Accuracy: 519/600 (86%)
#
# Initial Test Loss : 0.340024,
# Initial Test Accuracy : 86.500%
#
# Epoch: 396
# Train Loss: 0.444732 Acc: 0.8013
# Elapsed 13820.15s, 34.81 s/epoch, 0.46 s/batch, ets 104.43s
#
# Test set: Average loss: 0.3398, Accuracy: 516/600 (86%)
#
#
# Test set: Average loss: 0.3398, Accuracy: 516/600 (86%)
#
# Initial Test Loss : 0.339806,
# Initial Test Accuracy : 86.000%
#
# Epoch: 397
# Train Loss: 0.453091 Acc: 0.7987
# Elapsed 13853.99s, 34.81 s/epoch, 0.46 s/batch, ets 69.62s
#
# Test set: Average loss: 0.3270, Accuracy: 517/600 (86%)
#
#
# Test set: Average loss: 0.3270, Accuracy: 517/600 (86%)
#
# Initial Test Loss : 0.327031,
# Initial Test Accuracy : 86.167%
#
# Epoch: 398
# Train Loss: 0.463412 Acc: 0.8083
# Elapsed 13887.80s, 34.81 s/epoch, 0.46 s/batch, ets 34.81s
#
# Test set: Average loss: 0.3636, Accuracy: 512/600 (85%)
#
#
# Test set: Average loss: 0.3636, Accuracy: 512/600 (85%)
#
# Initial Test Loss : 0.363632,
# Initial Test Accuracy : 85.333%
#
# Epoch: 399
# Train Loss: 0.466066 Acc: 0.7892
# Elapsed 13921.58s, 34.80 s/epoch, 0.46 s/batch, ets 0.00s
#
# Test set: Average loss: 0.3849, Accuracy: 511/600 (85%)
#
# Total time: 13923.72, Best Loss: 0.313

# %% [markdown]
# ## <font style="color:blue">4.10. Loss and Accuracy Plot</font>

# %%
plot_loss_accuracy(train_loss=[train_loss], 
                   val_loss=[val_loss], 
                   train_acc=[train_acc], 
                   val_acc=[val_acc], 
                   colors=['blue'], 
                   loss_legend_loc='upper center', 
                   acc_legend_loc='upper left')

# %% [markdown]
# # <font style="color:blue">5. Sample Prediction</font>
#
# Show some sample predictions.

# %% [markdown]
# ## <font style="color:blue">5.1. Make Predictions</font>

# %%
def prediction(model, device, batch_input):
    
    # send model to cpu/cuda according to your system configuration
    model.to(device)
    
    # it is important to do model.eval() before prediction
    model.eval()

    data = batch_input.to(device)

    output = model(data)

    # Score to probability using softmax
    prob = F.softmax(output, dim=1)

    # get the max probability
    pred_prob = prob.data.max(dim=1)[0]
    
    # get the index of the max probability
    pred_index = prob.data.max(dim=1)[1]
    
    return pred_index.cpu().numpy(), pred_prob.cpu().numpy()

# %% [markdown]
# ## <font style="color:blue">5.2. Get predictions on a batch</font>

# %%
def get_sample_prediction(model, data_root, mean, std):
    batch_size = 15

    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
        
        
    
    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    data_len = test_dataset.__len__()
    
    interval = int(data_len/batch_size)
    
    imgs = []
    inputs = []
    targets = []
    for i in range(batch_size):
        index = i * interval
        trans_input, target = test_dataset_trans.__getitem__(index)
        img, _ = test_dataset.__getitem__(index)
        
        imgs.append(img)
        inputs.append(trans_input)
        targets.append(target)
        
    inputs = torch.stack(inputs)
        
    cls, prob = prediction(model, device, batch_input=inputs)
    
    plt.style.use('default')
    plt.rcParams["figure.figsize"] = (15, 9)
    fig = plt.figure()
    
    
    for i, target in enumerate(targets):
        plt.subplot(3, 5, i+1)
        img = transforms.functional.to_pil_image(imgs[i])
        plt.imshow(img)
        plt.gca().set_title('P:{0}({1:.2}), T:{2}'.format(test_dataset.classes[cls[i]], 
                                                     prob[i], 
                                                     test_dataset.classes[targets[i]]))
    fig.savefig('sample_prediction.png')
    plt.show()
    
    return

# %% [markdown]
# ## <font style="color:blue">5.3. Load Model and Run Inference</font>

# %%
m = MyModel()

m = load_model(m)

train_config = TrainingConfiguration()

test_data_path = os.path.join(train_config.data_root, 'validation')

train_data_path = os.path.join(train_config.data_root, 'training')

mean, std = get_mean_std(train_data_path)


get_sample_prediction(m, test_data_path, mean, std)
# Out:
# mean: tensor([0.4610, 0.4347, 0.3897]), std: tensor([0.2400, 0.2356, 0.2306])

# %% [markdown]
# You can see that even though the network is trained on a very small subset if data, the predictions are not that bad. This means that our model is ready to be trained.

# %% [markdown]
# # <font style="color:red">6. Display Confusion Matrix [10 Points]</font>
# Display the confusion matrix for the above problem. You can refer to the earlier lectures on Performance metrics for reference.
#
# The output should something similar to this:
#
# <img src='https://www.learnopencv.com/wp-content/uploads/2020/02/c3_w5_sample_confusion_matrix.png' width=600>

# %%
# YOUR CODE HERE
def get_id(classes, name):
    
    class_to_id = 0
    for i in range(len(classes)):
        if (name == classes[i]):
            class_to_id = i
            break;
    return class_to_id

def plot_confusion_matrix(classes, result):    
    
    figure = plt.figure() 
    axes = figure.add_subplot(111)     
    caxes = axes.matshow(result) 
    figure.colorbar(caxes)   
    axes.set_xticklabels([''] + classes) 
    axes.set_yticklabels([''] + classes)     
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    for j in range(result.shape[0]): 
        for i in range(result.shape[1]): 
            axes.text(i, j, result[j, i], color = 'black', ha = 'center', va = 'center')
            
    plt.show()
    

    return


def confusion_matrix(model, data_root, mean, std):    
    batch_size = 15
    
    if torch.cuda.is_available():
        device = "cuda"
        num_workers = 8
    else:
        device = "cpu"
        num_workers = 2
                
    
    # transformed data
    test_dataset_trans = datasets.ImageFolder(root=data_root, transform=image_common_transforms(mean, std))
    
    # original image dataset
    test_dataset = datasets.ImageFolder(root=data_root, transform=image_preprocess_transforms())
    
    classes = test_dataset.classes
    
    data_len = test_dataset.__len__()
    interval = int(data_len / batch_size)
        
    actuals = []
    predicts = []
    for i in range(interval):
        i_index = i * batch_size
        inputs = []
        imgs = []    
        targets = []
        for j in range(batch_size):
            index = i_index + j
            trans_input, target = test_dataset_trans.__getitem__(index)          
        
            inputs.append(trans_input)
            targets.append(target)
        
        inputs = torch.stack(inputs)    
        cls, prob = prediction(model, device, batch_input = inputs)
                               
        for t_i, target in enumerate(targets): 
            actuals.append(get_id(classes, test_dataset.classes[targets[t_i]]))
            predicts.append(get_id(classes, test_dataset.classes[cls[t_i]]))            
            
       
    k = len(np.unique(actuals)) # Number of classes 
    result = np.zeros((k, k))

  
    for i in range(len(actuals)):
        result[actuals[i]][predicts[i]] += 1    
    
    plot_confusion_matrix(classes, result)
    
    return

# %%
confusion_matrix(m, test_data_path, mean, std)

# %% [markdown]
# After you have completed the assignment, <font style="color:red">upload and submit the 2 notebooks and the models folder</font> on the portal so that we can check and provide feedback.
